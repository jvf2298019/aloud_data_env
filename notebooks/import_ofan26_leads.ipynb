# %% [markdown]
# # Tratamento de Lista Geral de Leads
# ## Objetivo: Esse pipeline tem como objetivo separar a lista de Leads disponível para disparos
#
# ### Campanha: lcto-ofan-jan26
# ### Conversion types: 1

# %%
# Importações básicas
import pandas as pd
import numpy as np
import sys
from pathlib import Path
import os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src'))

# Adiciona src ao path
sys.path.append('../src')

#

# Utilitários de dados
from data_utils import (
    load_raw_data,
    save_processed_data,
    remove_duplicates,
    handle_missing_values,
    detect_outliers,
    normalize_column,
    process_phone_string,
    process_phone_number,
    clean_and_lower_column,
    flatten_list_to_df,
    remove_buyers_from_dataframe
)

CRONOGRAMA_SUBDOMAIN = 'cronogramadosfluentes-xwamel'

# Utilitários SQL
from sql_utils import DatabaseConnection as Dbc, load_query_from_file

# Utilitários de visualização
import matplotlib.pyplot as plt
import seaborn as sns

# Utilitários de API
from api_utils import (
    make_request,
    get_json,
    post_json,
    paginated_request,
    response_to_dataframe
)

# utilitários hotmart
from hotmart_utils import Hotmart

# utilitários tmb
from tmb_utils import TMB   

# Configurações pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Load Database Driver
db = Dbc()

# Inicializar API Hotmart
hotmart = Hotmart()

# Inicializar API TMB
tmb = TMB()

print('✓ Importações concluídas com sucesso!')
# Out:
# ✓ Importações concluídas com sucesso!

# %% [markdown]
# ## Load Leads Dataframe

# %%
df = load_raw_data(
    "wtl_events_202601061128.csv"
)

# %%
from datetime import datetime, timezone
import math

conversions = []

def is_nan_or_none(val):
    return val is None or (isinstance(val, float) and math.isnan(val))

def clean_json_value(val):
    """
    Clean a single value to be JSON compliant, replacing nan/None with None and forcing types
    """
    if is_nan_or_none(val):
        return None
    if isinstance(val, float):
        # JSON does not support inf
        if math.isinf(val):
            return None
    return val

def to_iso_z(dt_str: str) -> str:
    """
    Entrada:  '2026-01-04 23:51:58.000 -0300'
    Saída:    '2026-01-05T02:51:58.000Z'  (UTC, com milissegundos e Z)
    """
    if is_nan_or_none(dt_str):
        return None
    try:
        dt = datetime.strptime(dt_str, "%Y-%m-%d %H:%M:%S.%f %z")   # tz-aware
        dt_utc = dt.astimezone(timezone.utc)
        return dt_utc.strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z"
    except Exception:
        return None

def make_json_compliant_dict(item):
    """
    Recursively replace values that are not JSON compliant (e.g., nan/None/inf) with None.
    """
    if isinstance(item, dict):
        return {k: make_json_compliant_dict(v) for k, v in item.items()}
    elif isinstance(item, list):
        return [make_json_compliant_dict(val) for val in item]
    else:
        return clean_json_value(item)

for idx, row in df.iterrows():
    # Defensive get and clean for all fields that might be nan
    email = row.get("field_email")
    email = "" if is_nan_or_none(email) else str(email).lower().strip()

    phone_val = row.get("field_phone")
    phone_str = "" if is_nan_or_none(phone_val) else str(phone_val).strip()
    phone = process_phone_number(phone_str)

    data_val = row.get("data")
    conversion_date = to_iso_z(data_val)

    campaign_id = clean_json_value(row.get("field_conversion"))
    utm_source = clean_json_value(row.get("utm_source"))
    utm_campaign = clean_json_value(row.get("utm_campaign"))
    utm_medium = clean_json_value(row.get("utm_medium"))
    utm_content = clean_json_value(row.get("utm_content"))
    url_page_path = clean_json_value(row.get("url_page_path"))

    conversion_dict = { 
        "lead_data": {
            "email": {"value": email},
            "phone": phone,
        }, 
        "conversion_data": {
            "conversion_date": conversion_date,
            "campaign_id": campaign_id,
            "conversion_type_id": "1",
            "utm_source": utm_source,
            "utm_campaign": utm_campaign,
            "utm_medium": utm_medium,
            "utm_content": utm_content,
            "conversion_raw_info": { 
                "page_url": url_page_path
            }
        },
        "flow_settings": {
            "skip_conversion": False,
            "skip_orquestration": True
        }
    }

    # Recursively clean before append to eliminate any possible nan or non-JSON-compliant values
    conversion_dict = make_json_compliant_dict(conversion_dict)
    conversions.append(conversion_dict)

conversions
# Out:
# [{'lead_data': {'email': {'value': 'vanessachaves22@hotmail.com'},
#    'phone': {'raw_phone_input': '(55) 21995-9579',
#     'formatted_phone': '+5555219959579',
#     'whatsapp_format': '+5555219959579',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:51:58.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'vanessachaves22@hotmail.com'},
#    'phone': {'raw_phone_input': '(55) 21995-9579',
#     'formatted_phone': '+5555219959579',
#     'whatsapp_format': '+5555219959579',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:51:57.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'guizamg321@gmail.com'},
#    'phone': {'raw_phone_input': '+5511983422698',
#     'formatted_phone': '+5511983422698',
#     'whatsapp_format': '+5511983422698',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:51:07.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240038577000140',
#    'utm_content': '120240040171810140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'venanciojacinto740@gmail.com'},
#    'phone': {'raw_phone_input': '+258852577125',
#     'formatted_phone': '+258852577125',
#     'whatsapp_format': '+258852577125',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 258,
#     'region': 'MZ',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:40:53.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'jacqueline.trabalhocs@gmail.com'},
#    'phone': {'raw_phone_input': '+5511984647958',
#     'formatted_phone': '+5511984647958',
#     'whatsapp_format': '+5511984647958',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:39:06.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'jacqueline.trabalhocs@gmail.com'},
#    'phone': {'raw_phone_input': '(55) 11984-6479',
#     'formatted_phone': '+5555119846479',
#     'whatsapp_format': '+5555119846479',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:38:40.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'joaodalagil@gmail.com'},
#    'phone': {'raw_phone_input': '+244947174517',
#     'formatted_phone': '+244947174517',
#     'whatsapp_format': '+244947174517',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 244,
#     'region': 'AO',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:27:36.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'tiktok',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'josepettidocs@gmail.com'},
#    'phone': {'raw_phone_input': '+13475960660',
#     'formatted_phone': '+13475960660',
#     'whatsapp_format': '+13475960660',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 1,
#     'region': 'US',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Fixed Line or Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:24:04.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'facebook',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'toweracabamentos@gmail.com'},
#    'phone': {'raw_phone_input': '+5547992068822',
#     'formatted_phone': '+5547992068822',
#     'whatsapp_format': '+554792068822',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 47,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Santa Catarina',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:22:58.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ghusantana20@gmail.com'},
#    'phone': {'raw_phone_input': '+5599985376867',
#     'formatted_phone': '+5599985376867',
#     'whatsapp_format': '+559985376867',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 99,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Maranhão',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:19:07.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'clariceassisdefreitasoliveira@gmail.com'},
#    'phone': {'raw_phone_input': '+5561994300356',
#     'formatted_phone': '+5561994300356',
#     'whatsapp_format': '+556194300356',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 61,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Distrito Federal',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:18:52.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'clariceassisdefreitasoliveira@gmail.com'},
#    'phone': {'raw_phone_input': '(61) 91206-056',
#     'formatted_phone': '+556191206056',
#     'whatsapp_format': '+556191206056',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 61,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:17:59.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'clariceassisdefreitasoliveira@gmail.com'},
#    'phone': {'raw_phone_input': '(61) 91206-056',
#     'formatted_phone': '+556191206056',
#     'whatsapp_format': '+556191206056',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 61,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:17:57.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'amanda.santos28@icloud.com'},
#    'phone': {'raw_phone_input': '+5548988765949',
#     'formatted_phone': '+5548988765949',
#     'whatsapp_format': '+554888765949',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 48,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Santa Catarina',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:17:34.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239869925070140',
#    'utm_medium': '120240433500130140',
#    'utm_content': '120240433500230140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v3/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'gibiniju@gmail.com'},
#    'phone': {'raw_phone_input': '+5511974091468',
#     'formatted_phone': '+5511974091468',
#     'whatsapp_format': '+5511974091468',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:11:00.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '{{campaign.id}}',
#    'utm_medium': '{{adset.id}}',
#    'utm_content': '{{ad.id}}',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'viniciusnunez27@outlook.com'},
#    'phone': {'raw_phone_input': '+5541985314045',
#     'formatted_phone': '+5541985314045',
#     'whatsapp_format': '+554185314045',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:03:51.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'instagram',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'story',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ldiascruzleca@gmail.com'},
#    'phone': {'raw_phone_input': '+5548996559766',
#     'formatted_phone': '+5548996559766',
#     'whatsapp_format': '+554896559766',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 48,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Santa Catarina',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T02:00:19.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'vg19926@gmail.com'},
#    'phone': {'raw_phone_input': '+5571993097242',
#     'formatted_phone': '+5571993097242',
#     'whatsapp_format': '+557193097242',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 71,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Bahia',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:57:23.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'vg19926@gmail.com'},
#    'phone': {'raw_phone_input': '+5571993097242',
#     'formatted_phone': '+5571993097242',
#     'whatsapp_format': '+557193097242',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 71,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Bahia',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:57:22.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'samukalves@gmail.com'},
#    'phone': {'raw_phone_input': '+5562999804901',
#     'formatted_phone': '+5562999804901',
#     'whatsapp_format': '+556299804901',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 62,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Goiás',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:57:14.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240381759560140',
#    'utm_medium': '120240381760720140',
#    'utm_content': '120240381871550140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'djzeanblog@gmail.com'},
#    'phone': {'raw_phone_input': '+5561986063519',
#     'formatted_phone': '+5561986063519',
#     'whatsapp_format': '+556186063519',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 61,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Distrito Federal',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:54:18.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239871000880140',
#    'utm_medium': '120239871001300140',
#    'utm_content': '120239871001780140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v6/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'eloisa36@hotmail.com'},
#    'phone': {'raw_phone_input': '+5535997526758',
#     'formatted_phone': '+5535997526758',
#     'whatsapp_format': '+553597526758',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 35,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:54:15.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'diegonunesdemoraes539@gmail.com'},
#    'phone': {'raw_phone_input': '+5551999018657',
#     'formatted_phone': '+5551999018657',
#     'whatsapp_format': '+555199018657',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 51,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Rio Grande do Sul',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:53:43.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'instagram',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'story',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'juninhobarbosasea@gmail.com'},
#    'phone': {'raw_phone_input': '+5592991163535',
#     'formatted_phone': '+5592991163535',
#     'whatsapp_format': '+559291163535',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 92,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Amazonas',
#     'timezone': ['America/Manaus'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:48:58.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240380770320140',
#    'utm_medium': '120240380771440140',
#    'utm_content': '120240381564130140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'pati.bolanho@yahoo.com.br'},
#    'phone': {'raw_phone_input': '+5511976603582',
#     'formatted_phone': '+5511976603582',
#     'whatsapp_format': '+5511976603582',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:48:48.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239870967650140',
#    'utm_medium': '120239870967820140',
#    'utm_content': '120239870968460140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v5/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'nathyamoraes@gmail.com'},
#    'phone': {'raw_phone_input': '+12394401677',
#     'formatted_phone': '+12394401677',
#     'whatsapp_format': '+12394401677',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 1,
#     'region': 'US',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Fixed Line or Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:47:10.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239958744380140',
#    'utm_medium': '120240433766760140',
#    'utm_content': '120240433767060140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'laurapaes360@gmail.com'},
#    'phone': {'raw_phone_input': '+5581988941816',
#     'formatted_phone': '+5581988941816',
#     'whatsapp_format': '+558188941816',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 81,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Pernambuco',
#     'timezone': ['America/Noronha'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:45:11.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'monalisactr27@gmail.com'},
#    'phone': {'raw_phone_input': '+5511988932419',
#     'formatted_phone': '+5511988932419',
#     'whatsapp_format': '+5511988932419',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:43:33.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'monalisactr27@gmail.com'},
#    'phone': {'raw_phone_input': '(11) 88932-419',
#     'formatted_phone': '+551188932419',
#     'whatsapp_format': '+551188932419',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:43:07.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'thiagosaxtos@gmail.com'},
#    'phone': {'raw_phone_input': '+351915677062',
#     'formatted_phone': '+351915677062',
#     'whatsapp_format': '+351915677062',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 351,
#     'region': 'PT',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:42:18.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240038576970140',
#    'utm_content': '120240040172690140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'thiagosaxtos@gmail.com'},
#    'phone': {'raw_phone_input': '351 915 677',
#     'formatted_phone': '+55351915677',
#     'whatsapp_format': '+55351915677',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': None,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:41:57.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240038576970140',
#    'utm_content': '120240040172690140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'pathysalgueiro@hotmail.com'},
#    'phone': {'raw_phone_input': '+5511970630758',
#     'formatted_phone': '+5511970630758',
#     'whatsapp_format': '+5511970630758',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:41:18.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239979066200140',
#    'utm_medium': '120239979067310140',
#    'utm_content': '120240026619800140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'rejdalpra@gmail.com'},
#    'phone': {'raw_phone_input': '+5545999938512',
#     'formatted_phone': '+5545999938512',
#     'whatsapp_format': '+554599938512',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 45,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:41:04.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'facebook',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'rafaelhkarczmarski@gmail.com'},
#    'phone': {'raw_phone_input': '+5541995825607',
#     'formatted_phone': '+5541995825607',
#     'whatsapp_format': '+554195825607',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:40:09.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ashnilo120@gmail.com'},
#    'phone': {'raw_phone_input': '+5579988922803',
#     'formatted_phone': '+5579988922803',
#     'whatsapp_format': '+557988922803',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 79,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Sergipe',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:36:16.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'aparecidojosegabriel48@gmail.com'},
#    'phone': {'raw_phone_input': '+5518998070628',
#     'formatted_phone': '+5518998070628',
#     'whatsapp_format': '+5518998070628',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 18,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:35:21.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'lemos.karoline@outlook.com'},
#    'phone': {'raw_phone_input': '+18439251293',
#     'formatted_phone': '+18439251293',
#     'whatsapp_format': '+18439251293',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 1,
#     'region': 'US',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Fixed Line or Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:24:04.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239958744380140',
#    'utm_medium': '120239958743980140',
#    'utm_content': '120239960265900140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'edmilsonshadowsjr@gmail.com'},
#    'phone': {'raw_phone_input': '+5555959916358',
#     'formatted_phone': '+5555959916358',
#     'whatsapp_format': '+555559916358',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Rio Grande do Sul',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:18:32.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240433898700140',
#    'utm_content': '120240433899190140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'andressasulamita474@gmail.com'},
#    'phone': {'raw_phone_input': '+5521969003376',
#     'formatted_phone': '+5521969003376',
#     'whatsapp_format': '+5521969003376',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 21,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Rio de Janeiro',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:15:12.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239869566410140',
#    'utm_medium': '120239869566130140',
#    'utm_content': '120239869565810140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v2/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'eduarda.gomed1@hotmail.com'},
#    'phone': {'raw_phone_input': '+5567991692762',
#     'formatted_phone': '+5567991692762',
#     'whatsapp_format': '+556791692762',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 67,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Mato Grosso do Sul',
#     'timezone': ['America/Manaus'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:13:33.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ricardo@ricocorretora.com'},
#    'phone': {'raw_phone_input': '+5565984785982',
#     'formatted_phone': '+5565984785982',
#     'whatsapp_format': '+556584785982',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 65,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Mato Grosso',
#     'timezone': ['America/Manaus'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:13:02.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'brunobueno.camps@gmail.com'},
#    'phone': {'raw_phone_input': '+5513988024671',
#     'formatted_phone': '+5513988024671',
#     'whatsapp_format': '+5513988024671',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 13,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:11:53.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'mvsoprj@gmail.com'},
#    'phone': {'raw_phone_input': '+5521965084368',
#     'formatted_phone': '+5521965084368',
#     'whatsapp_format': '+5521965084368',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 21,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Rio de Janeiro',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:10:19.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239870504580140',
#    'utm_medium': '120240433642030140',
#    'utm_content': '120240433642270140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'luanda.meireles@gmail.com'},
#    'phone': {'raw_phone_input': '+5569999762291',
#     'formatted_phone': '+5569999762291',
#     'whatsapp_format': '+556999762291',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 69,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Rondônia',
#     'timezone': ['America/Manaus'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:03:11.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'marciadesiqueira6@gmail.com'},
#    'phone': {'raw_phone_input': '+5555999339087',
#     'formatted_phone': '+5555999339087',
#     'whatsapp_format': '+555599339087',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Rio Grande do Sul',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:00:35.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': None,
#    'utm_campaign': None,
#    'utm_medium': None,
#    'utm_content': None,
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'marlycorretora10@gmail.com'},
#    'phone': {'raw_phone_input': '+5511985195259',
#     'formatted_phone': '+5511985195259',
#     'whatsapp_format': '+5511985195259',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T01:00:09.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240380770320140',
#    'utm_medium': '120240380771440140',
#    'utm_content': '120240381564130140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'tiagu.mb@gmail.com'},
#    'phone': {'raw_phone_input': '+5512991862505',
#     'formatted_phone': '+5512991862505',
#     'whatsapp_format': '+5512991862505',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 12,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:58:24.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'rosesantiago17@yahoo.com.br'},
#    'phone': {'raw_phone_input': '+5511987970631',
#     'formatted_phone': '+5511987970631',
#     'whatsapp_format': '+5511987970631',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:57:53.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239870504580140',
#    'utm_medium': '120240433642020140',
#    'utm_content': '120240433642150140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'c.magrii@yahoo.com.br'},
#    'phone': {'raw_phone_input': '+5515981113531',
#     'formatted_phone': '+5515981113531',
#     'whatsapp_format': '+5515981113531',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 15,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:54:47.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240038576970140',
#    'utm_content': '120240040172690140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'lucas_schroh@live.com'},
#    'phone': {'raw_phone_input': '+5542991131708',
#     'formatted_phone': '+5542991131708',
#     'whatsapp_format': '+554291131708',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 42,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:53:48.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'instagram',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'story',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'sousamateus612@gmail.com'},
#    'phone': {'raw_phone_input': '+5586999704811',
#     'formatted_phone': '+5586999704811',
#     'whatsapp_format': '+558699704811',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 86,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Piauí',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:52:42.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'guilhermejdsantos18@gmail.com'},
#    'phone': {'raw_phone_input': '+5511948929191',
#     'formatted_phone': '+5511948929191',
#     'whatsapp_format': '+5511948929191',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:48:51.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240433898790140',
#    'utm_content': '120240433898760140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'vntc28@gmail.com'},
#    'phone': {'raw_phone_input': '+5511946119866',
#     'formatted_phone': '+5511946119866',
#     'whatsapp_format': '+5511946119866',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:47:13.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240380770320140',
#    'utm_medium': '120240380771440140',
#    'utm_content': '120240381564130140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ozeiasfreitasdemiranda@gmail.com'},
#    'phone': {'raw_phone_input': '+5551993101553',
#     'formatted_phone': '+5551993101553',
#     'whatsapp_format': '+555193101553',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 51,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Rio Grande do Sul',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:46:03.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ozeiasfreitasdemiranda@gmail.com'},
#    'phone': {'raw_phone_input': '(55) 51993-1015',
#     'formatted_phone': '+55519931015',
#     'whatsapp_format': '+55519931015',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': None,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:45:54.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'anaelisasales6519@gmail.com'},
#    'phone': {'raw_phone_input': '+5546991346943',
#     'formatted_phone': '+5546991346943',
#     'whatsapp_format': '+554691346943',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 46,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:43:57.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'andrebaraberto@gmail.com'},
#    'phone': {'raw_phone_input': '+15082250999',
#     'formatted_phone': '+15082250999',
#     'whatsapp_format': '+15082250999',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 1,
#     'region': 'US',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Fixed Line or Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:37:08.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240035206480140',
#    'utm_medium': '120240035207840140',
#    'utm_content': '120240036728290140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'andrebaraberto@gmail.com'},
#    'phone': {'raw_phone_input': '+15082250999',
#     'formatted_phone': '+15082250999',
#     'whatsapp_format': '+15082250999',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 1,
#     'region': 'US',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Fixed Line or Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:37:07.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240035206480140',
#    'utm_medium': '120240035207840140',
#    'utm_content': '120240036728290140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'crislainedn0@gmail.com'},
#    'phone': {'raw_phone_input': '(55) 61981-1006',
#     'formatted_phone': '+5555619811006',
#     'whatsapp_format': '+5555619811006',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:34:34.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'douglasdrywall@yahoo.com'},
#    'phone': {'raw_phone_input': '+5541991254057',
#     'formatted_phone': '+5541991254057',
#     'whatsapp_format': '+554191254057',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-05T00:32:48.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
# ...
#     'whatsapp_format': '+554199755909',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:09:12.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'madeireiramadefe@gmail.com'},
#    'phone': {'raw_phone_input': '+5585992535515',
#     'formatted_phone': '+5585992535515',
#     'whatsapp_format': '+558592535515',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 85,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Ceará',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:08:12.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239869925070140',
#    'utm_medium': '120240433500130140',
#    'utm_content': '120240433500290140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v3/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'cristiana.nunes@gmail.com.com'},
#    'phone': {'raw_phone_input': '+5585996808543',
#     'formatted_phone': '+5585996808543',
#     'whatsapp_format': '+558596808543',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 85,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Ceará',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:07:18.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'jully.funy@gmail.com'},
#    'phone': {'raw_phone_input': '+5521981149355',
#     'formatted_phone': '+5521981149355',
#     'whatsapp_format': '+5521981149355',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 21,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Rio de Janeiro',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:07:15.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240038575800140',
#    'utm_medium': '120240038577000140',
#    'utm_content': '120240040171810140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'claricerv1@hotmail.com'},
#    'phone': {'raw_phone_input': '+5564999373820',
#     'formatted_phone': '+5564999373820',
#     'whatsapp_format': '+556499373820',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 64,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Goiás',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:06:48.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ssng201401@gmail.com'},
#    'phone': {'raw_phone_input': '+351964833611',
#     'formatted_phone': '+351964833611',
#     'whatsapp_format': '+351964833611',
#     'isValid': True,
#     'type': 'Internacional',
#     'ddd': None,
#     'ddi': 351,
#     'region': 'PT',
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:06:33.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'tiktok',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'adlkjsajk@gmail.com'},
#    'phone': {'raw_phone_input': '+5541999876546',
#     'formatted_phone': '+5541999876546',
#     'whatsapp_format': '+554199876546',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:06:29.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'adlkjsajk@gmail.com'},
#    'phone': {'raw_phone_input': '(39) 10283-2190',
#     'formatted_phone': '+5539102832190',
#     'whatsapp_format': '+5539102832190',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 39,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:06:24.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'brunaferreirabuc@gmail.com'},
#    'phone': {'raw_phone_input': '+5511940337872',
#     'formatted_phone': '+5511940337872',
#     'whatsapp_format': '+5511940337872',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:06:22.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'ncwellington@gmail.com'},
#    'phone': {'raw_phone_input': '+5511972612287',
#     'formatted_phone': '+5511972612287',
#     'whatsapp_format': '+5511972612287',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:05:48.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'pcoelho32@yahoo.com.br'},
#    'phone': {'raw_phone_input': '+5521993217847',
#     'formatted_phone': '+5521993217847',
#     'whatsapp_format': '+5521993217847',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 21,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Rio de Janeiro',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:54.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239979066200140',
#    'utm_medium': '120239979067200140',
#    'utm_content': '120240026621010140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'fabricio.ph9@gmail.com'},
#    'phone': {'raw_phone_input': '+5531999369636',
#     'formatted_phone': '+5531999369636',
#     'whatsapp_format': '+553199369636',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Telemig Celular',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:42.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'ig',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'social',
#    'utm_content': 'link_in_bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'cristianediasearaujo@gmail.com'},
#    'phone': {'raw_phone_input': '+5515996558424',
#     'formatted_phone': '+5515996558424',
#     'whatsapp_format': '+5515996558424',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 15,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:41.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239958744380140',
#    'utm_medium': '120239958744070140',
#    'utm_content': '120239960266530140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'novembro221@gmail.com'},
#    'phone': {'raw_phone_input': '+5584992049683',
#     'formatted_phone': '+5584992049683',
#     'whatsapp_format': '+558492049683',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 84,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Rio Grande do Norte',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:22.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'novembro221@gmail.com'},
#    'phone': {'raw_phone_input': '+5584992049683',
#     'formatted_phone': '+5584992049683',
#     'whatsapp_format': '+558492049683',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 84,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Rio Grande do Norte',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:21.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'youtube',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'joane34j7@gmail.com'},
#    'phone': {'raw_phone_input': '+5531994249812',
#     'formatted_phone': '+5531994249812',
#     'whatsapp_format': '+553194249812',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:14.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'facebook',
#    'utm_campaign': 'ppt-lpm-cdf',
#    'utm_medium': 'bio',
#    'utm_content': 'bio',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'cristianediasearaujo@gmail.com'},
#    'phone': {'raw_phone_input': '+5515996558424',
#     'formatted_phone': '+5515996558424',
#     'whatsapp_format': '+5515996558424',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 15,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:13.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120239958744380140',
#    'utm_medium': '120239958744070140',
#    'utm_content': '120239960266530140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v1/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'chok.import@gmail.com'},
#    'phone': {'raw_phone_input': '+5511951785219',
#     'formatted_phone': '+5511951785219',
#     'whatsapp_format': '+5511951785219',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:11.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240035206480140',
#    'utm_medium': '120240433843530140',
#    'utm_content': '120240433843280140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'chok.import@gmail.com'},
#    'phone': {'raw_phone_input': '+5511951785219',
#     'formatted_phone': '+5511951785219',
#     'whatsapp_format': '+5511951785219',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:04:10.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240035206480140',
#    'utm_medium': '120240433843530140',
#    'utm_content': '120240433843280140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  {'lead_data': {'email': {'value': 'chok.import@gmail.com'},
#    'phone': {'raw_phone_input': '(55) 11951-7852',
#     'formatted_phone': '+5555119517852',
#     'whatsapp_format': '+5555119517852',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 55,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown'}},
#   'conversion_data': {'conversion_date': '2026-01-04T11:03:59.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '1',
#    'utm_source': 'meta-ads',
#    'utm_campaign': '120240035206480140',
#    'utm_medium': '120240433843530140',
#    'utm_content': '120240433843280140',
#    'conversion_raw_info': {'page_url': '/pc-ofan-v4/'}},
#   'flow_settings': {'skip_conversion': False, 'skip_orquestration': True}},
#  ...]

# %%
import requests
import time
import json
import os

BASE_URL = "https://webhooks.aloud.com.br/data/ce7d3845-3acf-4606-835c-63485eb5fe70"

responses = []

PERSISTENCE_FILE = "imported_leads.json"

# Carregue os registros persistidos previamente já enviados, se existir
if os.path.exists(PERSISTENCE_FILE):
    with open(PERSISTENCE_FILE, "r", encoding="utf-8") as f:
        imported_leads = set(json.load(f))
else:
    imported_leads = set()

total_to_import = len(conversions)
print(f"Total de registros para importar: {total_to_import}")

for idx, item in enumerate(conversions, start=1):
    email = (item.get("lead_data", {}).get("email", {}).get("value") or "").lower().strip()
    if not email:
        print(f"Registro {idx} ignorado: email ausente ou inválido.")
        continue
    if email in imported_leads:
        print(f"Registro {idx} já foi importado anteriormente para o email '{email}', ignorando.")
        continue
    
    print(f"Importando registro {idx} de {total_to_import}... ({email})")
    response = requests.post(BASE_URL, json=item)
    try:
        resp_json = response.json()
    except Exception:
        resp_json = response.text
    responses.append(resp_json)
    
    # Atualize a persistência local imediatamente
    imported_leads.add(email)
    with open(PERSISTENCE_FILE, "w", encoding="utf-8") as f:
        json.dump(sorted(list(imported_leads)), f, ensure_ascii=False, indent=2)
    
    time.sleep(1)

responses
# Out:
# Total de registros para importar: 2342
# Registro 1 já foi importado anteriormente para o email 'vanessachaves22@hotmail.com', ignorando.
# Registro 2 já foi importado anteriormente para o email 'vanessachaves22@hotmail.com', ignorando.
# Registro 3 já foi importado anteriormente para o email 'guizamg321@gmail.com', ignorando.
# Registro 4 já foi importado anteriormente para o email 'venanciojacinto740@gmail.com', ignorando.
# Registro 5 já foi importado anteriormente para o email 'jacqueline.trabalhocs@gmail.com', ignorando.
# Registro 6 já foi importado anteriormente para o email 'jacqueline.trabalhocs@gmail.com', ignorando.
# Registro 7 já foi importado anteriormente para o email 'joaodalagil@gmail.com', ignorando.
# Registro 8 já foi importado anteriormente para o email 'josepettidocs@gmail.com', ignorando.
# Registro 9 já foi importado anteriormente para o email 'toweracabamentos@gmail.com', ignorando.
# Registro 10 já foi importado anteriormente para o email 'ghusantana20@gmail.com', ignorando.
# Registro 11 já foi importado anteriormente para o email 'clariceassisdefreitasoliveira@gmail.com', ignorando.
# Registro 12 já foi importado anteriormente para o email 'clariceassisdefreitasoliveira@gmail.com', ignorando.
# Registro 13 já foi importado anteriormente para o email 'clariceassisdefreitasoliveira@gmail.com', ignorando.
# Registro 14 já foi importado anteriormente para o email 'amanda.santos28@icloud.com', ignorando.
# Registro 15 já foi importado anteriormente para o email 'gibiniju@gmail.com', ignorando.
# Registro 16 já foi importado anteriormente para o email 'viniciusnunez27@outlook.com', ignorando.
# Registro 17 já foi importado anteriormente para o email 'ldiascruzleca@gmail.com', ignorando.
# Registro 18 já foi importado anteriormente para o email 'vg19926@gmail.com', ignorando.
# Registro 19 já foi importado anteriormente para o email 'vg19926@gmail.com', ignorando.
# Registro 20 já foi importado anteriormente para o email 'samukalves@gmail.com', ignorando.
# Registro 21 já foi importado anteriormente para o email 'djzeanblog@gmail.com', ignorando.
# Registro 22 já foi importado anteriormente para o email 'eloisa36@hotmail.com', ignorando.
# Registro 23 já foi importado anteriormente para o email 'diegonunesdemoraes539@gmail.com', ignorando.
# Registro 24 já foi importado anteriormente para o email 'juninhobarbosasea@gmail.com', ignorando.
# Registro 25 já foi importado anteriormente para o email 'pati.bolanho@yahoo.com.br', ignorando.
# Registro 26 já foi importado anteriormente para o email 'nathyamoraes@gmail.com', ignorando.
# Registro 27 já foi importado anteriormente para o email 'laurapaes360@gmail.com', ignorando.
# Registro 28 já foi importado anteriormente para o email 'monalisactr27@gmail.com', ignorando.
# Registro 29 já foi importado anteriormente para o email 'monalisactr27@gmail.com', ignorando.
# Registro 30 já foi importado anteriormente para o email 'thiagosaxtos@gmail.com', ignorando.
# Registro 31 já foi importado anteriormente para o email 'thiagosaxtos@gmail.com', ignorando.
# Registro 32 já foi importado anteriormente para o email 'pathysalgueiro@hotmail.com', ignorando.
# Registro 33 já foi importado anteriormente para o email 'rejdalpra@gmail.com', ignorando.
# Registro 34 já foi importado anteriormente para o email 'rafaelhkarczmarski@gmail.com', ignorando.
# Registro 35 já foi importado anteriormente para o email 'ashnilo120@gmail.com', ignorando.
# Registro 36 já foi importado anteriormente para o email 'aparecidojosegabriel48@gmail.com', ignorando.
# Registro 37 já foi importado anteriormente para o email 'lemos.karoline@outlook.com', ignorando.
# Registro 38 já foi importado anteriormente para o email 'edmilsonshadowsjr@gmail.com', ignorando.
# Registro 39 já foi importado anteriormente para o email 'andressasulamita474@gmail.com', ignorando.
# Registro 40 já foi importado anteriormente para o email 'eduarda.gomed1@hotmail.com', ignorando.
# Registro 41 já foi importado anteriormente para o email 'ricardo@ricocorretora.com', ignorando.
# Registro 42 já foi importado anteriormente para o email 'brunobueno.camps@gmail.com', ignorando.
# Registro 43 já foi importado anteriormente para o email 'mvsoprj@gmail.com', ignorando.
# Registro 44 já foi importado anteriormente para o email 'luanda.meireles@gmail.com', ignorando.
# Registro 45 já foi importado anteriormente para o email 'marciadesiqueira6@gmail.com', ignorando.
# Registro 46 já foi importado anteriormente para o email 'marlycorretora10@gmail.com', ignorando.
# Registro 47 já foi importado anteriormente para o email 'tiagu.mb@gmail.com', ignorando.
# Registro 48 já foi importado anteriormente para o email 'rosesantiago17@yahoo.com.br', ignorando.
# Registro 49 já foi importado anteriormente para o email 'c.magrii@yahoo.com.br', ignorando.
# Registro 50 já foi importado anteriormente para o email 'lucas_schroh@live.com', ignorando.
# Registro 51 já foi importado anteriormente para o email 'sousamateus612@gmail.com', ignorando.
# Registro 52 já foi importado anteriormente para o email 'guilhermejdsantos18@gmail.com', ignorando.
# Registro 53 já foi importado anteriormente para o email 'vntc28@gmail.com', ignorando.
# Registro 54 já foi importado anteriormente para o email 'ozeiasfreitasdemiranda@gmail.com', ignorando.
# Registro 55 já foi importado anteriormente para o email 'ozeiasfreitasdemiranda@gmail.com', ignorando.
# Registro 56 já foi importado anteriormente para o email 'anaelisasales6519@gmail.com', ignorando.
# Registro 57 já foi importado anteriormente para o email 'andrebaraberto@gmail.com', ignorando.
# Registro 58 já foi importado anteriormente para o email 'andrebaraberto@gmail.com', ignorando.
# Registro 59 já foi importado anteriormente para o email 'crislainedn0@gmail.com', ignorando.
# Registro 60 já foi importado anteriormente para o email 'douglasdrywall@yahoo.com', ignorando.
# Registro 61 já foi importado anteriormente para o email 'cm.caiomoreira@gmail.com', ignorando.
# Registro 62 já foi importado anteriormente para o email 'ingryd.valim@hotmail.com', ignorando.
# Registro 63 já foi importado anteriormente para o email 'gbrunhari@icloud.com', ignorando.
# Registro 64 já foi importado anteriormente para o email 'raffatriindade@gmail.com', ignorando.
# Registro 65 já foi importado anteriormente para o email 'caio.medeiros@v4company.com', ignorando.
# Registro 66 já foi importado anteriormente para o email 'ana.86.rj@gmail.com', ignorando.
# Registro 67 já foi importado anteriormente para o email 'contatoviniciusgomes@gmail.com', ignorando.
# Registro 68 já foi importado anteriormente para o email 'maciel.je@hotmail.com', ignorando.
# Registro 69 já foi importado anteriormente para o email 'gabrielbleal17@gmail.com', ignorando.
# Registro 70 já foi importado anteriormente para o email 'gabrielluis50@hotmail.com', ignorando.
# Registro 71 já foi importado anteriormente para o email 'vitoriaglopes171@icloud.com', ignorando.
# Registro 72 já foi importado anteriormente para o email 'matheusgyw@gmail.com', ignorando.
# Registro 73 já foi importado anteriormente para o email 'izorzanelli@yahoo.com.br', ignorando.
# Registro 74 já foi importado anteriormente para o email 'ppbjuniorr2@gmail.com', ignorando.
# Registro 75 já foi importado anteriormente para o email 'karinelemos2803@gmail.com', ignorando.
# Registro 76 já foi importado anteriormente para o email 'allyson_alves_@outlook.com', ignorando.
# Registro 77 já foi importado anteriormente para o email 'paulosancho82@gmail.com', ignorando.
# Registro 78 já foi importado anteriormente para o email 'ellemvieira21@gmail.com', ignorando.
# Registro 79 já foi importado anteriormente para o email 'andrecte2@gmail.com', ignorando.
# Registro 80 já foi importado anteriormente para o email 'cristiano.mcon@gmail.com', ignorando.
# Registro 81 já foi importado anteriormente para o email 'luciano-costa@outlook.com', ignorando.
# Registro 82 já foi importado anteriormente para o email 'delinhadiniz2@gmail.com', ignorando.
# Registro 83 já foi importado anteriormente para o email 'gleiceduartelino17@gmail.com', ignorando.
# Registro 84 já foi importado anteriormente para o email 'elizamarnunesfm@gmail.com', ignorando.
# Registro 85 já foi importado anteriormente para o email 'maryggomes4@gmail.com', ignorando.
# Registro 86 já foi importado anteriormente para o email 'maryggomes4@gmail.com', ignorando.
# Registro 87 já foi importado anteriormente para o email 'maryggomes4@gmail.com', ignorando.
# Registro 88 já foi importado anteriormente para o email 'larissalopes1415@gmail.com', ignorando.
# Registro 89 já foi importado anteriormente para o email 'larissalopes1415@gmail.com', ignorando.
# Registro 90 já foi importado anteriormente para o email 'wellingtonoliveira1988@gmail.com', ignorando.
# Registro 91 já foi importado anteriormente para o email 'brunobarrinovo@gmail.com', ignorando.
# Registro 92 já foi importado anteriormente para o email 'lrcassola@yahoo.com.br', ignorando.
# Registro 93 já foi importado anteriormente para o email 'lrcassola@yahoo.com.br', ignorando.
# Registro 94 já foi importado anteriormente para o email 'bruno2ksantos@gmail.com', ignorando.
# Registro 95 já foi importado anteriormente para o email 'rafaeladvogado@yahoo.com.br', ignorando.
# Registro 96 já foi importado anteriormente para o email 'gabrielforover@gmail.com', ignorando.
# Registro 97 já foi importado anteriormente para o email 'layanepaulina1996@gmail.com', ignorando.
# Registro 98 já foi importado anteriormente para o email 'hannah-leah1@hotmail.com', ignorando.
# Registro 99 já foi importado anteriormente para o email 'mauricio@mauriciofreitas.pro.br', ignorando.
# Registro 100 já foi importado anteriormente para o email 'patriciohelioraul@gmail.com', ignorando.
# Registro 101 já foi importado anteriormente para o email 'mauricio@mauriciofreitas.pro.br', ignorando.
# Registro 102 já foi importado anteriormente para o email 'rodrigoju_338@hotmail.com', ignorando.
# Registro 103 já foi importado anteriormente para o email 'wlysses@gmail.com', ignorando.
# Registro 104 já foi importado anteriormente para o email 'beatrizpadovani@outlook.com', ignorando.
# Registro 105 já foi importado anteriormente para o email 'renatomnetto@gmail.com', ignorando.
# Registro 106 já foi importado anteriormente para o email 'joaodanielpantoja77@gmail.com', ignorando.
# Registro 107 já foi importado anteriormente para o email 'wesley006.oliveira@gmail.com', ignorando.
# Registro 108 já foi importado anteriormente para o email 'karol_lina2008@hotmail.com', ignorando.
# Registro 109 já foi importado anteriormente para o email 'jana_davanco@hotmail.com', ignorando.
# Registro 110 já foi importado anteriormente para o email 'julianemoreira751@gmail.com', ignorando.
# Registro 111 já foi importado anteriormente para o email 'andree.cons@gmail.com', ignorando.
# Registro 112 já foi importado anteriormente para o email 'lu_marquess@hotmail.com', ignorando.
# Registro 113 já foi importado anteriormente para o email 'daviklug1@gmail.com', ignorando.
# Registro 114 já foi importado anteriormente para o email 'felipedede3456@gmail.com', ignorando.
# Registro 115 já foi importado anteriormente para o email 'luana_sturaro@hotmail.com', ignorando.
# Registro 116 já foi importado anteriormente para o email 'luana_sturaro@hotmail.com', ignorando.
# Registro 117 já foi importado anteriormente para o email 'brdcruz@gmail.com', ignorando.
# Registro 118 já foi importado anteriormente para o email 'leandro.bairros11@gmail.com', ignorando.
# Registro 119 já foi importado anteriormente para o email 'ludisegundo@gmail.com', ignorando.
# Registro 120 já foi importado anteriormente para o email 'adrianaelarissa10@gmail.com', ignorando.
# Registro 121 já foi importado anteriormente para o email 'itanarezende@gmail.com', ignorando.
# Registro 122 já foi importado anteriormente para o email 'leandro.bairros11@gmail.com', ignorando.
# Registro 123 já foi importado anteriormente para o email 'diegoxecxec@gmail.com', ignorando.
# Registro 124 já foi importado anteriormente para o email 'lucasvendrameto883@gmail.com', ignorando.
# Registro 125 já foi importado anteriormente para o email 'lucasvendrameto883@gmail.com', ignorando.
# Registro 126 já foi importado anteriormente para o email 'kayronhenrique.med@gmail.com', ignorando.
# Registro 127 já foi importado anteriormente para o email 'mariasilvamaciel17@gmail.com', ignorando.
# Registro 128 já foi importado anteriormente para o email 'tayaneferreira_@hotmail.com', ignorando.
# Registro 129 já foi importado anteriormente para o email 'emanueldalmoro333@gmail.com', ignorando.
# Registro 130 já foi importado anteriormente para o email 'marciaca@terra.com.br', ignorando.
# Registro 131 já foi importado anteriormente para o email 'amandacarollinyadv@gmail.com', ignorando.
# Registro 132 já foi importado anteriormente para o email 'danielaalbano@hotmail.com', ignorando.
# Registro 133 já foi importado anteriormente para o email 'maxcimily@gmail.com', ignorando.
# Registro 134 já foi importado anteriormente para o email 'aimee_vieira26@hotmail.com', ignorando.
# Registro 135 já foi importado anteriormente para o email 'lucasvianalopes16@gmail.com', ignorando.
# Registro 136 já foi importado anteriormente para o email 'lucasvianalopes16@gmail.com', ignorando.
# Registro 137 já foi importado anteriormente para o email 'rayanpinho23@gmail.com', ignorando.
# Registro 138 já foi importado anteriormente para o email 'dheymessomlima83@gmail.com', ignorando.
# Registro 139 já foi importado anteriormente para o email 'kamilasjcs2@outlook.com', ignorando.
# Registro 140 já foi importado anteriormente para o email 'gilmarj001@gmail.com', ignorando.
# Registro 141 já foi importado anteriormente para o email 'talitabmarinho@gmail.com', ignorando.
# Registro 142 já foi importado anteriormente para o email 'joycepinheiro183@gmail.com', ignorando.
# Registro 143 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 144 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 145 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 146 já foi importado anteriormente para o email 'reder.aclinicas@gmail.com', ignorando.
# Registro 147 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 148 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 149 já foi importado anteriormente para o email 'leviferreira185@gmail.com', ignorando.
# Registro 150 já foi importado anteriormente para o email 'vhnoronha@hotmail.com', ignorando.
# Registro 151 já foi importado anteriormente para o email 'danieloliveiradesls12@gmail.com', ignorando.
# Registro 152 já foi importado anteriormente para o email 'danieloliveiradesls12@gmail.com', ignorando.
# Registro 153 já foi importado anteriormente para o email 'danieloliveiradesls12@gmail.com', ignorando.
# Registro 154 já foi importado anteriormente para o email 'danieloliveiradesls12@gmail.com', ignorando.
# Registro 155 já foi importado anteriormente para o email 'danieloliveiradesls12@gmail.com', ignorando.
# Registro 156 já foi importado anteriormente para o email 'henrique070289@gmail.com', ignorando.
# Registro 157 já foi importado anteriormente para o email 'gabriela_silvaol@hotmail.com', ignorando.
# Registro 158 já foi importado anteriormente para o email 'washingtonunai33@gmail.com', ignorando.
# Registro 159 já foi importado anteriormente para o email 'bruno.lopes1986@live.com', ignorando.
# Registro 160 já foi importado anteriormente para o email 'thatiane_garcia682@hotmail.com', ignorando.
# Registro 161 já foi importado anteriormente para o email 'thaisinteriores79@gmail.com', ignorando.
# Registro 162 já foi importado anteriormente para o email 'barone@nwbenergia.com', ignorando.
# Registro 163 já foi importado anteriormente para o email 'marcelapfingstag@gmail.com', ignorando.
# Registro 164 já foi importado anteriormente para o email 'cbolutavicius@gmail.com', ignorando.
# Registro 165 já foi importado anteriormente para o email 'ninobruno882@gmail.com', ignorando.
# Registro 166 já foi importado anteriormente para o email 'ninobruno882@gmail.com', ignorando.
# Registro 167 já foi importado anteriormente para o email 'julyene97@gmail.com', ignorando.
# Registro 168 já foi importado anteriormente para o email 'tatianecfagundes@gmail.com', ignorando.
# Registro 169 já foi importado anteriormente para o email 'tiagodosantospereira@gmail.com', ignorando.
# Registro 170 já foi importado anteriormente para o email 'juliano.casantos1995@gmail.com', ignorando.
# Registro 171 já foi importado anteriormente para o email 'tiagodosantospereira@gmail.com', ignorando.
# Registro 172 já foi importado anteriormente para o email 'deusfiel279@gmail.com', ignorando.
# Registro 173 já foi importado anteriormente para o email 'marcosfernandesuk@outlook.com', ignorando.
# Registro 174 já foi importado anteriormente para o email 'ju.mribeiro@hotmail.com', ignorando.
# Registro 175 já foi importado anteriormente para o email 'sarahgoncalvesbtrabalho@gmail.com', ignorando.
# Registro 176 já foi importado anteriormente para o email 'gustavopiresjr@gmail.com', ignorando.
# Registro 177 já foi importado anteriormente para o email 'marasouza.jns@gmail.com', ignorando.
# Registro 178 já foi importado anteriormente para o email 'brenarocha550@gmail.com', ignorando.
# Registro 179 já foi importado anteriormente para o email 'janicsmajximo@gmail.com', ignorando.
# Registro 180 já foi importado anteriormente para o email 'oliver.carlossantosp@gmail.com', ignorando.
# Registro 181 já foi importado anteriormente para o email 'renanalvescavalari@gmail.com', ignorando.
# Registro 182 já foi importado anteriormente para o email 'adrianosribeiro@icloud.com', ignorando.
# Registro 183 já foi importado anteriormente para o email 'lleticiasabrinadossantos@gmail.com', ignorando.
# Registro 184 já foi importado anteriormente para o email 'chrismendonca2018@gmail.com', ignorando.
# Registro 185 já foi importado anteriormente para o email 'davi.rarau@hotmail.com', ignorando.
# Registro 186 já foi importado anteriormente para o email 'crismfranco@hotmail.com', ignorando.
# Registro 187 já foi importado anteriormente para o email 'pryfreitas47@gmail.com', ignorando.
# Registro 188 já foi importado anteriormente para o email 'amandacamposn23@gmail.com', ignorando.
# Registro 189 já foi importado anteriormente para o email 'sarahemy.oliveira0204@gmail.com', ignorando.
# Registro 190 já foi importado anteriormente para o email 'bhiane@hotmail.com', ignorando.
# Registro 191 já foi importado anteriormente para o email 'gustavogc1863@gmail.com', ignorando.
# Registro 192 já foi importado anteriormente para o email 'srmanos22@gmail.com', ignorando.
# Registro 193 já foi importado anteriormente para o email 'bia_oliveiras95@hotmail.com', ignorando.
# Registro 194 já foi importado anteriormente para o email 'brbrennand@gmail.com', ignorando.
# Registro 195 já foi importado anteriormente para o email 'mendoncajessica958@gmail.com', ignorando.
# Registro 196 já foi importado anteriormente para o email 'irneybrito@yahoo.com.br', ignorando.
# Registro 197 já foi importado anteriormente para o email 'studiosolarsustentabilidade@gmail.com', ignorando.
# Registro 198 já foi importado anteriormente para o email 'dallyane.guedes@tcmeng.com.br', ignorando.
# Registro 199 já foi importado anteriormente para o email 'flaviomatheus104@gmail.com', ignorando.
# Registro 200 já foi importado anteriormente para o email 'nataliaoliveira099@gmail.com', ignorando.
# Registro 201 já foi importado anteriormente para o email 'claudia.schallenberg@yahoo.com', ignorando.
# Registro 202 já foi importado anteriormente para o email 'wandermatheusom@icloud.com', ignorando.
# Registro 203 já foi importado anteriormente para o email 'mayrarodriguesztto@gmail.com', ignorando.
# Registro 204 já foi importado anteriormente para o email 'grbraghetto@gmail.com', ignorando.
# Registro 205 já foi importado anteriormente para o email 'juanasousa62@gmail.com', ignorando.
# Registro 206 já foi importado anteriormente para o email 'thomazfromano@icloud.com', ignorando.
# Registro 207 já foi importado anteriormente para o email 'roqueleandro018@gmail.com', ignorando.
# Registro 208 já foi importado anteriormente para o email 'phizato@gmail.com', ignorando.
# Registro 209 já foi importado anteriormente para o email 'joellorena60@gmail.com', ignorando.
# Registro 210 já foi importado anteriormente para o email 'camiladuarte.andrade@gmail.com', ignorando.
# Registro 211 já foi importado anteriormente para o email 'drarico@hotmail.com', ignorando.
# Registro 212 já foi importado anteriormente para o email 'prismirand@gmail.com', ignorando.
# Registro 213 já foi importado anteriormente para o email 'phr_assis@hotmail.com', ignorando.
# Registro 214 já foi importado anteriormente para o email 'paulasanty@gmail.com', ignorando.
# Registro 215 já foi importado anteriormente para o email 'celio.xavier@outlook.com', ignorando.
# Registro 216 já foi importado anteriormente para o email 'arielwav191@gmail.com', ignorando.
# Registro 217 já foi importado anteriormente para o email 'bpsantiagu@gmail.com', ignorando.
# Registro 218 já foi importado anteriormente para o email 'cristianodavy233@gmail.com', ignorando.
# Registro 219 já foi importado anteriormente para o email 'nathalia_100@hotmail.com', ignorando.
# Registro 220 já foi importado anteriormente para o email 'luizsalvadorcostaigor@gmail.com', ignorando.
# Registro 221 já foi importado anteriormente para o email 'solangeabs2020@gmail.com', ignorando.
# Registro 222 já foi importado anteriormente para o email 'babibnogueira@gmail.com', ignorando.
# Registro 223 já foi importado anteriormente para o email 'lealananda22@gmail.com', ignorando.
# Registro 224 já foi importado anteriormente para o email 'jocastacm@gmail.com', ignorando.
# Registro 225 já foi importado anteriormente para o email 'josiminyjoaquim@gmail.com', ignorando.
# Registro 226 já foi importado anteriormente para o email 'teuzinho_51@msn.com', ignorando.
# Registro 227 já foi importado anteriormente para o email 'josiminyjoaquim@gmail.com', ignorando.
# Registro 228 já foi importado anteriormente para o email 'felipe.kleto@yahoo.com.br', ignorando.
# Registro 229 já foi importado anteriormente para o email 'matheussmkt@gmail.com', ignorando.
# Registro 230 já foi importado anteriormente para o email 'scmoraes@gmail.com', ignorando.
# Registro 231 já foi importado anteriormente para o email 'lucianoaf369@gmail.com', ignorando.
# Registro 232 já foi importado anteriormente para o email 'jannesousa20@gmail.com', ignorando.
# Registro 233 já foi importado anteriormente para o email 'alexandrelino463@gmail.com', ignorando.
# Registro 234 já foi importado anteriormente para o email 'ferrazdasilvaluciana@gmail.com', ignorando.
# Registro 235 já foi importado anteriormente para o email 'ferrazdasilvaluciana@gmail.com', ignorando.
# Registro 236 já foi importado anteriormente para o email 'joannysilverio05@gmail.com', ignorando.
# Registro 237 já foi importado anteriormente para o email 'ruanabreuvalin56789@gmail.com', ignorando.
# Registro 238 já foi importado anteriormente para o email 'amanda.lucio.moscardi@gmail.com', ignorando.
# Registro 239 já foi importado anteriormente para o email 'miladias.hp@gmail.com', ignorando.
# Registro 240 já foi importado anteriormente para o email 'henriquepixeldata@icloud.com', ignorando.
# Registro 241 já foi importado anteriormente para o email 'paulo.silas4@gmail.com', ignorando.
# Registro 242 já foi importado anteriormente para o email 'figueiradafoz01@gmail.com', ignorando.
# Registro 243 já foi importado anteriormente para o email 'perindara1@gmail.com', ignorando.
# Registro 244 já foi importado anteriormente para o email 'zignanibarroso@gmail.com', ignorando.
# Registro 245 já foi importado anteriormente para o email 'paulphisyque@gmail.com', ignorando.
# Registro 246 já foi importado anteriormente para o email 'sabrinaguterres@gmail.com', ignorando.
# Registro 247 já foi importado anteriormente para o email 'dianifranco26@gmail.com', ignorando.
# Registro 248 já foi importado anteriormente para o email 'larissa.veterinarian@gmail.com', ignorando.
# Registro 249 já foi importado anteriormente para o email 'leonardorocha31@gmail.com', ignorando.
# Registro 250 já foi importado anteriormente para o email 'amuhflores@gmail.com', ignorando.
# Registro 251 já foi importado anteriormente para o email 'lanaisanches@gmail.com', ignorando.
# Registro 252 já foi importado anteriormente para o email 'arbalexandrecrod@gmail.com', ignorando.
# Registro 253 já foi importado anteriormente para o email 'm4rio.clj@gmail.com', ignorando.
# Registro 254 já foi importado anteriormente para o email 'luizfelipe65727@gmail.com', ignorando.
# Registro 255 já foi importado anteriormente para o email 'rvanusasantos@yahoo.com.br', ignorando.
# Registro 256 já foi importado anteriormente para o email 'carolfidelis@hotmail.com', ignorando.
# Registro 257 já foi importado anteriormente para o email 'marcelomendes.ps@gmail.com', ignorando.
# Registro 258 já foi importado anteriormente para o email 'israellobo007@gmail.com', ignorando.
# Registro 259 já foi importado anteriormente para o email 'araujodossantosc91@gmail.com', ignorando.
# Registro 260 já foi importado anteriormente para o email 'tatianammacedo@gmail.com', ignorando.
# Registro 261 já foi importado anteriormente para o email 'juniorelyuk@gmail.com', ignorando.
# Registro 262 já foi importado anteriormente para o email 'juniorelyuk@gmail.com', ignorando.
# Registro 263 já foi importado anteriormente para o email 'renatagusmaothorp@yahoo.com.br', ignorando.
# Registro 264 já foi importado anteriormente para o email 'jose135augustoliveira@gmail.com', ignorando.
# Registro 265 já foi importado anteriormente para o email 'luna.marques.borges.10@gmail.com', ignorando.
# Registro 266 já foi importado anteriormente para o email 'luna.marques.borges.10@gmail.com', ignorando.
# Registro 267 já foi importado anteriormente para o email 'luna.marques.borges.10@gmail.com', ignorando.
# Registro 268 já foi importado anteriormente para o email 'gabrielafagundesjaques@gmail.com', ignorando.
# Registro 269 já foi importado anteriormente para o email 'manoelcunhajunior@hotmail.com', ignorando.
# Registro 270 já foi importado anteriormente para o email 'manoelcunhajunior@hotmail.com', ignorando.
# Registro 271 já foi importado anteriormente para o email 'mariasg0304@gmail.com', ignorando.
# Registro 272 já foi importado anteriormente para o email 'lourdesdiniz46@gmail.com', ignorando.
# Registro 273 já foi importado anteriormente para o email 'icaroalmeidasousa124@gmail.com', ignorando.
# Registro 274 já foi importado anteriormente para o email 'cronaldoribeirodeandrade@gmail.com', ignorando.
# Registro 275 já foi importado anteriormente para o email 'cronaldoribeirodeandrade@gmail.com', ignorando.
# Registro 276 já foi importado anteriormente para o email 'pereira.renata04@yahoo.com', ignorando.
# Registro 277 já foi importado anteriormente para o email 'tecbrum@gmail.com', ignorando.
# Registro 278 já foi importado anteriormente para o email 'ddjrenato@gmail.com', ignorando.
# Registro 279 já foi importado anteriormente para o email 'ferreira.richele19@gmail.com', ignorando.
# Registro 280 já foi importado anteriormente para o email 'cgranemann@gmail.com', ignorando.
# Registro 281 já foi importado anteriormente para o email 'val_fabro@hotmail.com', ignorando.
# Registro 282 já foi importado anteriormente para o email 'leandroadmtorrinha@gmail.com', ignorando.
# Registro 283 já foi importado anteriormente para o email 'ktariffe@gmail.com', ignorando.
# Registro 284 já foi importado anteriormente para o email 'cgranemann@gmail.com', ignorando.
# Registro 285 já foi importado anteriormente para o email 'keciamelo.viana@gmail.com', ignorando.
# Registro 286 já foi importado anteriormente para o email 'thipossi@gmail.com', ignorando.
# Registro 287 já foi importado anteriormente para o email 'rspinellisaris@gmail.com', ignorando.
# Registro 288 já foi importado anteriormente para o email 'karlinhos.kalvin332@gmail.com', ignorando.
# Registro 289 já foi importado anteriormente para o email 'lucas.vangelista159@hotmail.com', ignorando.
# Registro 290 já foi importado anteriormente para o email 'rofofys2004@yahoo.com.br', ignorando.
# Registro 291 já foi importado anteriormente para o email 'latorre.vanessacm@gmail.com', ignorando.
# Registro 292 já foi importado anteriormente para o email 'latorre.vanessacm@gmail.com', ignorando.
# Registro 293 já foi importado anteriormente para o email 'kemelly.saraiva2000@gmail.com', ignorando.
# Registro 294 já foi importado anteriormente para o email 'kemelly.saraiva2000@gmail.com', ignorando.
# Registro 295 já foi importado anteriormente para o email 'kemelly.saraiva2000@gmail.com', ignorando.
# Registro 296 já foi importado anteriormente para o email 'luancarlosjn@gmail.com', ignorando.
# Registro 297 já foi importado anteriormente para o email 'sthefanie.jardim-pinho@hotmail.com', ignorando.
# Registro 298 já foi importado anteriormente para o email 'alex.bezerra80@hotmail.com', ignorando.
# Registro 299 já foi importado anteriormente para o email 'rafaelribeiroa89@gmail.com', ignorando.
# Registro 300 já foi importado anteriormente para o email 'ritabritoabygail@gmail.com', ignorando.
# Registro 301 já foi importado anteriormente para o email 'davi.agm@gmail.com', ignorando.
# Registro 302 já foi importado anteriormente para o email 'davi.agm@gmail.com', ignorando.
# Registro 303 já foi importado anteriormente para o email 'marquinho.cirilo@yahoo.com.br', ignorando.
# Registro 304 já foi importado anteriormente para o email 'germana270619.mor2019mor@gmail.com', ignorando.
# Registro 305 já foi importado anteriormente para o email 'marcelosant123@hotmail.com', ignorando.
# Registro 306 já foi importado anteriormente para o email 'alanaab52@gmail.com', ignorando.
# Registro 307 já foi importado anteriormente para o email 'santosnancivaldo1@gmail.com', ignorando.
# Registro 308 já foi importado anteriormente para o email 'gustavoaltino497@gmail.com', ignorando.
# Registro 309 já foi importado anteriormente para o email 'joao.zorato12@gmail.com', ignorando.
# Registro 310 já foi importado anteriormente para o email 'simonedavid@yahoo.com.br', ignorando.
# Registro 311 já foi importado anteriormente para o email 'brendon_duarte@hotmail.com', ignorando.
# Registro 312 já foi importado anteriormente para o email 'alessandra.sms.souza@gmail.com', ignorando.
# Registro 313 já foi importado anteriormente para o email 'artursilva.n2000@gmail.com', ignorando.
# Registro 314 já foi importado anteriormente para o email 'manez7616@gmail.com', ignorando.
# Registro 315 já foi importado anteriormente para o email 'leticiaalvesf38@gmail.com', ignorando.
# Registro 316 já foi importado anteriormente para o email 'gabi_ceppli@hotmail.com', ignorando.
# Registro 317 já foi importado anteriormente para o email 'gabi_ceppli@hotmail.com', ignorando.
# Registro 318 já foi importado anteriormente para o email 'lopesalcantara92@gmail.com', ignorando.
# Registro 319 já foi importado anteriormente para o email 'liviamorinfinito@gmail.com', ignorando.
# Registro 320 já foi importado anteriormente para o email 'liviamorinfinito@gmail.com', ignorando.
# Registro 321 já foi importado anteriormente para o email 'liviamorinfinito@gmail.com', ignorando.
# Registro 322 já foi importado anteriormente para o email 'vanessaliberato646@gmail.com', ignorando.
# Registro 323 já foi importado anteriormente para o email 'jgilliardmc@gmail.com', ignorando.
# Registro 324 já foi importado anteriormente para o email 'kleberluc132@gmail.com', ignorando.
# Registro 325 já foi importado anteriormente para o email 'kleberluc132@gmail.com', ignorando.
# Registro 326 já foi importado anteriormente para o email 'elipcgo@gmail.com', ignorando.
# Registro 327 já foi importado anteriormente para o email 'kellhenrique10@gmail.com', ignorando.
# Registro 328 já foi importado anteriormente para o email 'rericapaula@hotmail.com', ignorando.
# Registro 329 já foi importado anteriormente para o email 'daniloh13@hotmail.com', ignorando.
# Registro 330 já foi importado anteriormente para o email 'ra_fa_minervino@hotmail.com', ignorando.
# Registro 331 já foi importado anteriormente para o email 'danieleliam.dm2@gmail.com', ignorando.
# Registro 332 já foi importado anteriormente para o email 'danieleliam.dm2@gmail.com', ignorando.
# Registro 333 já foi importado anteriormente para o email 'dennis.dl626@gmail.com', ignorando.
# Registro 334 já foi importado anteriormente para o email 'randesonsoares09@gmail.com', ignorando.
# Registro 335 já foi importado anteriormente para o email 'murilosantanadavid75@gmail.com', ignorando.
# Registro 336 já foi importado anteriormente para o email 'erikadomingos2224@gmail.com', ignorando.
# Registro 337 já foi importado anteriormente para o email 'isaaccarvalheiro1@gmail.com', ignorando.
# Registro 338 já foi importado anteriormente para o email 'maguilherme528@gmail.com', ignorando.
# Registro 339 já foi importado anteriormente para o email 'andressawillog@gmail.com', ignorando.
# Registro 340 já foi importado anteriormente para o email 'caiquecosta301020@gmail.com', ignorando.
# Registro 341 já foi importado anteriormente para o email 'janainasilva280715@gmail.com', ignorando.
# Registro 342 já foi importado anteriormente para o email 'danielgp653@gmail.com', ignorando.
# Registro 343 já foi importado anteriormente para o email 'elyzandra2015@gmail.com', ignorando.
# Registro 344 já foi importado anteriormente para o email 'elyzandra2015@gmail.com', ignorando.
# Registro 345 já foi importado anteriormente para o email 'victor.liuti22@gmail.com', ignorando.
# Registro 346 já foi importado anteriormente para o email 'amandacardoso82@yahoo.com.br', ignorando.
# Registro 347 já foi importado anteriormente para o email 'caliman.wendell@gmail.com', ignorando.
# Registro 348 já foi importado anteriormente para o email 'caliman.wendell@gmail.com', ignorando.
# Registro 349 já foi importado anteriormente para o email 'walterhedevan10@gmail.com', ignorando.
# Registro 350 já foi importado anteriormente para o email 'psds73@gmail.com', ignorando.
# Registro 351 já foi importado anteriormente para o email 'pamela.xavier14@outlook.com', ignorando.
# Registro 352 já foi importado anteriormente para o email 'fabio.vnirdsilva@gmail.com', ignorando.
# Registro 353 já foi importado anteriormente para o email 'fabio.vnirdsilva@gmail.com', ignorando.
# Registro 354 já foi importado anteriormente para o email 'dejigo.executivo@gmail.com', ignorando.
# Registro 355 já foi importado anteriormente para o email 'marianoend@gmail.com', ignorando.
# Registro 356 já foi importado anteriormente para o email 'gustavoflorentino205@gmail.com', ignorando.
# Registro 357 já foi importado anteriormente para o email 'amandamelo_pe@hotmail.com', ignorando.
# Registro 358 já foi importado anteriormente para o email 'paularenatanunesmiranda@gmail.com', ignorando.
# Registro 359 já foi importado anteriormente para o email 'rofrancalaguna@gmail.com', ignorando.
# Registro 360 já foi importado anteriormente para o email 'dragabriela.odontopediatria@gmail.com', ignorando.
# Registro 361 já foi importado anteriormente para o email 'rosileiausa24@gmail.com', ignorando.
# Registro 362 já foi importado anteriormente para o email 'wiliers@terra.com.br', ignorando.
# Registro 363 já foi importado anteriormente para o email 'brunohsrosa@live.com', ignorando.
# Registro 364 já foi importado anteriormente para o email 'rosileiausa24@gmail.com', ignorando.
# Registro 365 já foi importado anteriormente para o email 'wuelsport21@gmail.com', ignorando.
# Registro 366 já foi importado anteriormente para o email 'su.verillo@gmail.com', ignorando.
# Registro 367 já foi importado anteriormente para o email 'thayschinaglia@gmail.com', ignorando.
# Registro 368 já foi importado anteriormente para o email 'natalialeitenunesl@gmail.com', ignorando.
# Registro 369 já foi importado anteriormente para o email 'caioarsantos88@gmail.com', ignorando.
# Registro 370 já foi importado anteriormente para o email 'ccrochaaa@gmail.com', ignorando.
# Registro 371 já foi importado anteriormente para o email 'andrielly2011.ribeiro@gmail.com', ignorando.
# Registro 372 já foi importado anteriormente para o email 'amcharchar@gmail.com', ignorando.
# Registro 373 já foi importado anteriormente para o email 'rodrigovilarinhocarvalho@gmail.com', ignorando.
# Registro 374 já foi importado anteriormente para o email 'brunoperanzetta@gmail.com', ignorando.
# Registro 375 já foi importado anteriormente para o email 'jessiemorais.jm@gmail.com', ignorando.
# Registro 376 já foi importado anteriormente para o email 'brunoperanzetta@gmail.com', ignorando.
# Registro 377 já foi importado anteriormente para o email 'alvesgilbert19@gmail.com', ignorando.
# Registro 378 já foi importado anteriormente para o email 'fabiscorrea280@gmail.com', ignorando.
# Registro 379 já foi importado anteriormente para o email 'juarezcll33@gmail.com', ignorando.
# Registro 380 já foi importado anteriormente para o email 'marcilio_fg@hotmail.com', ignorando.
# Registro 381 já foi importado anteriormente para o email 'felipepz1@hotmail.com.br', ignorando.
# Registro 382 já foi importado anteriormente para o email 'gilmarafialho321@gmail.com', ignorando.
# Registro 383 já foi importado anteriormente para o email 'sitgesbrasil@gmail.com', ignorando.
# Registro 384 já foi importado anteriormente para o email 'dwsilvamail@hotmail.com', ignorando.
# Registro 385 já foi importado anteriormente para o email 'sitgesbrasil@gmail.com', ignorando.
# Registro 386 já foi importado anteriormente para o email 'tonymanreza@gmail.com', ignorando.
# Registro 387 já foi importado anteriormente para o email 'karolinesoousa124@hotmail.com', ignorando.
# Registro 388 já foi importado anteriormente para o email 'jose.feltrim.urologia@gmail.com', ignorando.
# Registro 389 já foi importado anteriormente para o email 'carcarine20@gmail.com', ignorando.
# Registro 390 já foi importado anteriormente para o email 'tangor00@hotmail.com', ignorando.
# Registro 391 já foi importado anteriormente para o email 'walissonhenriquetimoteodasilva@gmail.com', ignorando.
# Registro 392 já foi importado anteriormente para o email 'isabellymarangaonunes@gmail.com', ignorando.
# Registro 393 já foi importado anteriormente para o email 'thaisafelix.comercial@gmail.com', ignorando.
# Registro 394 já foi importado anteriormente para o email 'juliosebastiaobernardo@gmail.com', ignorando.
# Registro 395 já foi importado anteriormente para o email 'juliosebastiaobernardo@gmail.com', ignorando.
# Registro 396 já foi importado anteriormente para o email 'leiajesus641@gmail.com', ignorando.
# Registro 397 já foi importado anteriormente para o email 'jhonatangoncalves6@gmail.com', ignorando.
# Registro 398 já foi importado anteriormente para o email 'pignaneliabreu@hotmail.com', ignorando.
# Registro 399 já foi importado anteriormente para o email 'noemidegraca@gmail.com', ignorando.
# Registro 400 já foi importado anteriormente para o email 'jessicagoncalves.lima@gmail.com', ignorando.
# Registro 401 já foi importado anteriormente para o email 'rafael_as_s@hotmail.com', ignorando.
# Registro 402 já foi importado anteriormente para o email 'emillyeduardarodrigues10@gmail.com', ignorando.
# Registro 403 já foi importado anteriormente para o email 'jhoefreitasuber@gmail.com', ignorando.
# Registro 404 já foi importado anteriormente para o email 'gcavalcanti@papirus.com', ignorando.
# Registro 405 já foi importado anteriormente para o email 'brunabh@gmail.com', ignorando.
# Registro 406 já foi importado anteriormente para o email 'salesraquel.rs@gmail.com', ignorando.
# Registro 407 já foi importado anteriormente para o email 'luanacouto8@outlook.com', ignorando.
# Registro 408 já foi importado anteriormente para o email 'wagner.erlich@gmail.com', ignorando.
# Registro 409 já foi importado anteriormente para o email 'mendoncaperesjpro@outlook.com', ignorando.
# Registro 410 já foi importado anteriormente para o email 'tulliorasec@gmail.com', ignorando.
# Registro 411 já foi importado anteriormente para o email 'anaclaraalvessantos667@gmail.com', ignorando.
# Registro 412 já foi importado anteriormente para o email 'santos.isafer@gmail.com', ignorando.
# Registro 413 já foi importado anteriormente para o email 'mariangelacouto3@gmail.com', ignorando.
# Registro 414 já foi importado anteriormente para o email 'kemyllylsm@icloud.com', ignorando.
# Registro 415 já foi importado anteriormente para o email 'kemyllylsm@icloud.com', ignorando.
# Registro 416 já foi importado anteriormente para o email 'hjoao2640@gmail.com', ignorando.
# Registro 417 já foi importado anteriormente para o email 'andreia.rod19011@gmail.com', ignorando.
# Registro 418 já foi importado anteriormente para o email 'andreia.rod19011@gmail.com', ignorando.
# Registro 419 já foi importado anteriormente para o email 'andreia.rod19011@gmail.com', ignorando.
# Registro 420 já foi importado anteriormente para o email 'teteu.lima1988@gmail.com', ignorando.
# Registro 421 já foi importado anteriormente para o email 'rafaeladaomarques@gmail.com', ignorando.
# Registro 422 já foi importado anteriormente para o email 'teteu.lima1988@gmail.com', ignorando.
# Registro 423 já foi importado anteriormente para o email 'alenigre@gmail.com', ignorando.
# Registro 424 já foi importado anteriormente para o email 'alenigre@gmail.com', ignorando.
# Registro 425 já foi importado anteriormente para o email 'alenigre@gmail.com', ignorando.
# Registro 426 já foi importado anteriormente para o email 'alenigre@gmail.com', ignorando.
# Registro 427 já foi importado anteriormente para o email 'alenigre@gmail.com', ignorando.
# Registro 428 já foi importado anteriormente para o email 'ce_martan_silva@hotmail.com', ignorando.
# Registro 429 já foi importado anteriormente para o email 'sinistrosaf.rafael@gmail.com', ignorando.
# Registro 430 já foi importado anteriormente para o email 'ce_martan_silva@hotmail.com', ignorando.
# Registro 431 já foi importado anteriormente para o email 'rhadassamuraiare@gmail.com', ignorando.
# Registro 432 já foi importado anteriormente para o email 'vitoriasana14@gmail.com', ignorando.
# Registro 433 já foi importado anteriormente para o email 'jozelereis@gmail.com', ignorando.
# Registro 434 já foi importado anteriormente para o email 'marhhcoutinho@gmail.com', ignorando.
# Registro 435 já foi importado anteriormente para o email 'vitoriasana14@gmail.com', ignorando.
# Registro 436 já foi importado anteriormente para o email 'rafaelaneves001@gmail.com', ignorando.
# Registro 437 já foi importado anteriormente para o email 'vitoriasana14@gmail.com', ignorando.
# Registro 438 já foi importado anteriormente para o email 'eudimeiasoares123@gmail.com', ignorando.
# Registro 439 já foi importado anteriormente para o email 'thakuraoka@gmail.com', ignorando.
# Registro 440 já foi importado anteriormente para o email 'arthurguizela@gmail.com.br', ignorando.
# Registro 441 já foi importado anteriormente para o email 'jalmir.diomario@gmail.com', ignorando.
# Registro 442 já foi importado anteriormente para o email 'clariceapj@hotmail.com', ignorando.
# Registro 443 já foi importado anteriormente para o email 'jusantanasouza24@gmail.com', ignorando.
# Registro 444 já foi importado anteriormente para o email 'pedro.henryque.ph09@gmail.com', ignorando.
# Registro 445 já foi importado anteriormente para o email 'jerffersonpedrosa.adv@gmail.com', ignorando.
# Registro 446 já foi importado anteriormente para o email 'raquelferalves9@gmail.com', ignorando.
# Registro 447 já foi importado anteriormente para o email 'jusantanasouza24@gmail.com', ignorando.
# Registro 448 já foi importado anteriormente para o email 'pedro.henryque.ph09@gmail.com', ignorando.
# Registro 449 já foi importado anteriormente para o email 'farides199725@icloud.com', ignorando.
# Registro 450 já foi importado anteriormente para o email 'batera.romulo@gmail.com', ignorando.
# Registro 451 já foi importado anteriormente para o email 'gabrielsquaresma@gmail.com', ignorando.
# Registro 452 já foi importado anteriormente para o email 'dudydasbomb@gmail.com', ignorando.
# Registro 453 já foi importado anteriormente para o email 'jenifferleao5@gmail.com', ignorando.
# Registro 454 já foi importado anteriormente para o email 'richardrichard8540@gmail.com', ignorando.
# Registro 455 já foi importado anteriormente para o email 'dani.sntcarvalho@gmail.com', ignorando.
# Registro 456 já foi importado anteriormente para o email 'juh.apgs@gmail.com', ignorando.
# Registro 457 já foi importado anteriormente para o email 'jssgaviao.74@gmail.com', ignorando.
# Registro 458 já foi importado anteriormente para o email 'elizabethlimbergerlopes@hotmail.com', ignorando.
# Registro 459 já foi importado anteriormente para o email 'elizabethlimbergerlopes@hotmail.com', ignorando.
# Registro 460 já foi importado anteriormente para o email 'hermanfrancis2004@hotmail.com', ignorando.
# Registro 461 já foi importado anteriormente para o email 'assiseliene@hotmail.com', ignorando.
# Registro 462 já foi importado anteriormente para o email 'gusmao.anderson@gmail.com', ignorando.
# Registro 463 já foi importado anteriormente para o email 'alissonviniciushj@gmail.com', ignorando.
# Registro 464 já foi importado anteriormente para o email 'luciananahimbogomesfilipe@gmail.com', ignorando.
# Registro 465 já foi importado anteriormente para o email 'thiagolsm99@hotmail.com', ignorando.
# Registro 466 já foi importado anteriormente para o email 'myss_2008@hotmail.com', ignorando.
# Registro 467 já foi importado anteriormente para o email 'daianegranja1990@gmail.com', ignorando.
# Registro 468 já foi importado anteriormente para o email 'eduardasantini6@gmail.com', ignorando.
# Registro 469 já foi importado anteriormente para o email 'dayhaneh@gmail.com', ignorando.
# Registro 470 já foi importado anteriormente para o email 'luizafrancodelima2020@gmail.com', ignorando.
# Registro 471 já foi importado anteriormente para o email 'rafawerle84@hotmail.com', ignorando.
# Registro 472 já foi importado anteriormente para o email 'gleyk.suelbe@gmail.com', ignorando.
# Registro 473 já foi importado anteriormente para o email 'claromurillo@gmail.com', ignorando.
# Registro 474 já foi importado anteriormente para o email 'rafawill086@gmail.com', ignorando.
# Registro 475 já foi importado anteriormente para o email 'wellingtonquaresma1998@gmail.com', ignorando.
# Registro 476 já foi importado anteriormente para o email 'lekamillo@gmail.com', ignorando.
# Registro 477 já foi importado anteriormente para o email 'francaresolve@gmail.com', ignorando.
# Registro 478 já foi importado anteriormente para o email 'palomaalves.per@gmail.com', ignorando.
# Registro 479 já foi importado anteriormente para o email 'pires.lara2005@gmail.com', ignorando.
# Registro 480 já foi importado anteriormente para o email 'lencinir@gmail.com', ignorando.
# Registro 481 já foi importado anteriormente para o email 'cintiassleal@gmail.com', ignorando.
# Registro 482 já foi importado anteriormente para o email 'palomaalves.per@gmail.com', ignorando.
# Registro 483 já foi importado anteriormente para o email 'bholiveira.web@gmail.com', ignorando.
# Registro 484 já foi importado anteriormente para o email 'aninhacarolmol@gmail.com', ignorando.
# Registro 485 já foi importado anteriormente para o email 'santanasil74@gmail.com', ignorando.
# Registro 486 já foi importado anteriormente para o email 'santanasil74@gmail.com', ignorando.
# Registro 487 já foi importado anteriormente para o email 'bonitobruno90@gmail.com', ignorando.
# Registro 488 já foi importado anteriormente para o email 'elainec.lacerda@hotmail.com', ignorando.
# Registro 489 já foi importado anteriormente para o email 'domingasalves6877@gmail.com', ignorando.
# Registro 490 já foi importado anteriormente para o email 'fabricioamrl@gmail.com', ignorando.
# Registro 491 já foi importado anteriormente para o email 'anamariaaguiara3@gmail.com', ignorando.
# Registro 492 já foi importado anteriormente para o email 'anamariaaguiara3@gmail.com', ignorando.
# Registro 493 já foi importado anteriormente para o email 'emersonsantos7886@hotmail.com', ignorando.
# Registro 494 já foi importado anteriormente para o email 'andre.adr@hotmail.com', ignorando.
# Registro 495 já foi importado anteriormente para o email 'deborasposito@icloud.com', ignorando.
# Registro 496 já foi importado anteriormente para o email 'yuriodesigneranddeveloper@hotmail.com', ignorando.
# ...
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'},
#  {'message': 'Workflow was started'}]
