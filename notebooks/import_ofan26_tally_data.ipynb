# %% [markdown]
# # Importação Retroativa de Dados
# Objetivo: Esse pipeline tem como objetivo realizar a importação retroativa dos dados de Pesquisa do Tally Forms.
#
# Campanha: lcto-ofan-jan26
# Conversion types: 2

# %% [markdown]
# # 0. Importando Dependências

# %%
# Importações básicas
import math
import pandas as pd
import numpy as np
import sys
from pathlib import Path
import os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), 'src'))

# Adiciona src ao path
sys.path.append('../src')


# Utilitários de dados
from data_utils import (
    load_raw_data,
    save_processed_data,
    remove_duplicates,
    handle_missing_values,
    detect_outliers,
    normalize_column,
    process_phone_string,
    process_phone_number,
    clean_and_lower_column,
    flatten_list_to_df,
    remove_buyers_from_dataframe
)

CRONOGRAMA_SUBDOMAIN = 'cronogramadosfluentes-xwamel'

# Utilitários SQL
from sql_utils import DatabaseConnection as Dbc, load_query_from_file

# Utilitários de visualização
import matplotlib.pyplot as plt
import seaborn as sns

# Utilitários de API
from api_utils import (
    make_request,
    get_json,
    post_json,
    paginated_request,
    response_to_dataframe
)

# utilitários hotmart
from hotmart_utils import Hotmart

# utilitários tmb
from tmb_utils import TMB   

# utilitários tally
from tally_utils import Tally  

# Configurações pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Load Database Driver
db = Dbc()

# Inicializar API Hotmart
hotmart = Hotmart()
# Inicializar API TMB
tmb = TMB()

# Inicializar API Tally Forms
tally = Tally()

# %% [markdown]
# # 1. Recuperando Submissões via API Tally Forms

# %%
## Constates do Código
CAMPAIGN_ID = 'lcto-ofan-jan26'
CONVERSION_TYPE_ID = "2"
FORM_ID = "Y5P1AN"

# Configurações de Importação
DESTINATION_QUEUE = 'S.NORM.PROD.NEW'
SKIP_ORQUESTRATION = True
SKIP_CONVERSION = False

## Recuperando Submissões via API Export
submissions = load_raw_data("tally_responses.csv")

# %% [markdown]
# ## 1.1 Formatando Dataframe Submissions

# %%
def clean_data(submissions):
    # Drop rows with missing data in columns: 'email', 'phone'
    submissions = submissions.dropna(subset=['email', 'phone'])
    submissions['phone'] = submissions['phone'].astype(int).astype(str) 
    def to_iso_z_apply(value, tz_local: str = "America/Sao_Paulo") -> str | None:
        if pd.isna(value):
            return None
        dt = pd.to_datetime(value, errors="coerce")
        if pd.isna(dt):
            return None
        # se vier tz-naive, assume GMT-3 (America/Sao_Paulo)
        if dt.tzinfo is None:
            dt = dt.tz_localize(tz_local)
        # converte pra UTC e formata
        dt_utc = dt.tz_convert("UTC")
        return dt_utc.strftime("%Y-%m-%dT%H:%M:%S.000Z")
    submissions["conversion_date"] = submissions["Submitted at"].apply(to_iso_z_apply)
    return submissions

submissions_clean = clean_data(submissions.copy())
submissions_clean.head()
# Out:
#      Submission ID Respondent ID         Submitted at utm_source  \
# 1648       ja4j8px       pbO0RjV  2025-12-30 13:58:13   whatsapp
# 1649       ja4j8YE       Gxloqvj  2025-12-30 13:58:32   whatsapp
# 1650       ja4jAla       1AVbNE1  2025-12-30 14:01:23   whatsapp
# 1651       Y5B1APv       q4VYJ9g  2025-12-30 14:06:30   whatsapp
# 1652       ja4jVLx       7RxJpRP  2025-12-30 14:07:55   whatsapp
#
#          utm_campaign utm_medium utm_content  utm_term  active_id  \
# 1648  lcto-ofan-jan26     direct  Onboarding       NaN        NaN
# 1649  lcto-ofan-jan26     direct  Onboarding       NaN        NaN
# 1650  lcto-ofan-jan26     direct  Onboarding       NaN        NaN
# 1651  lcto-ofan-jan26     direct  Onboarding       NaN        NaN
# 1652  lcto-ofan-jan26     direct  Onboarding       NaN        NaN
#
#           campaign_id  score                                name  \
# 1648  lcto-ofan-jan26     58  Fernanda Damasceno do Amaral Mello
# 1649  lcto-ofan-jan26     93               Marcos Paulo Mendonça
# 1650  lcto-ofan-jan26     48             Fabíola Soares do Monte
# 1651  lcto-ofan-jan26     88                Rodrigo Lima Corrêa
# 1652  lcto-ofan-jan26     33            Raquel Lopes dos Santos
#
#                                email          phone   country     gender  \
# 1648  fernanda.amaralmello@gmail.com  5541991635720    Brasil   Feminino
# 1649            marcosspt2@gmail.com  5511918831009    Brasil  Masculino
# 1650          fabiolamonte@gmail.com  5531984619327    Brasil   Feminino
# 1651        rodriguinhogda@gmail.com   351966675494  Portugal  Masculino
# 1652    raquellopezsmile@hotmail.com  5517981485015    Brasil   Feminino
#
#             age_range current_occupation  \
# 1648  De 25 a 30 anos       Empregado(a)
# 1649  De 31 a 34 anos    Empreendedor(a)
# 1650  De 45 a 54 anos           Autônomo
# 1651  De 25 a 30 anos       Empregado(a)
# 1652  De 25 a 30 anos       Dona de casa
#
#                                  biggest_fluency_desire  \
# 1648  Conseguir um aumento/promoção no meu emprego a...
# 1649                                 Morar no exterior.
# 1650             Dominar a gramática da lingua inglesa.
# 1651                      Conquistar um emprego melhor.
# 1652                                 Morar no exterior.
#
#                        monthy_income       english_level took_english_course  \
# 1648     De R$ 3001,00 a R$ 5.000,00      Intermediário.                Não.
# 1649  De R$ 10.000,00 a R$ 30.000,00              Básico                Sim.
# 1650     De R$ 3001,00 a R$ 5.000,00  Começando do zero.                Não.
# 1651    De R$ 5001,00 a R$ 10.000,00              Básico                Sim.
# 1652         Não tenho nenhuma renda              Básico                Não.
#
#                conversion_date
# 1648  2025-12-30T16:58:13.000Z
# 1649  2025-12-30T16:58:32.000Z
# 1650  2025-12-30T17:01:23.000Z
# 1651  2025-12-30T17:06:30.000Z
# 1652  2025-12-30T17:07:55.000Z

# %% [markdown]
# ## 1.2 Formatando Dataframe em formato Conversions

# %%
conversions = []

def is_nan_or_none(val):
    return val is None or (isinstance(val, float) and math.isnan(val))

def clean_json_value(val):
    """
    Clean a single value to be JSON compliant, replacing nan/None with None and forcing types
    """
    if is_nan_or_none(val):
        return None
    if isinstance(val, float):
        # JSON does not support inf
        if math.isinf(val):
            return None
    return val

def make_json_compliant_dict(item):
    """
    Recursively replace values that are not JSON compliant (e.g., nan/None/inf) with None.
    """
    if isinstance(item, dict):
        return {k: make_json_compliant_dict(v) for k, v in item.items()}
    elif isinstance(item, list):
        return [make_json_compliant_dict(val) for val in item]
    else:
        return clean_json_value(item)

for idx, row in submissions_clean.iterrows():

    # name
    name = clean_json_value(row.get("name"))
    # Defensive get and clean for all fields that might be nan
    email = row.get("email")
    email = "" if is_nan_or_none(email) else str(email).lower().strip()

    phone_val = row.get("phone")
    phone_str = "" if is_nan_or_none(phone_val) else str(phone_val).strip()
    phone = process_phone_number(phone_str)

    phone['raw_phone'] =  phone['raw_phone_input']

    conversion_date = clean_json_value(row.get("conversion_date"))

    utm_source = clean_json_value(row.get("utm_source"))
    utm_campaign = clean_json_value(row.get("utm_campaign"))
    utm_medium = clean_json_value(row.get("utm_medium"))
    utm_content = clean_json_value(row.get("utm_content"))
    submission_id = clean_json_value(row.get("Submission ID"))

    # Criando Conversion Raw Info Dictionary
    conversion_raw_info = {
        "form_id": FORM_ID,
        "submission_id": clean_json_value(row.get("Submission ID"))
    }
    labels = ["country", "gender", "age_range", "current_occupation", "biggest_fluency_desire", "monthy_income", "english_level", "took_english_course"]
    for label in labels:
        conversion_raw_info[label] = clean_json_value(row.get(label))

    conversion_dict = { 
        "lead_data": {
            "email": {"value": email},
            "phone": phone,
            "name": name
        }, 
        "conversion_data": {
            "conversion_date": conversion_date,
            "campaign_id": CAMPAIGN_ID,
            "conversion_type_id": CONVERSION_TYPE_ID,
            "utm_source": utm_source,
            "utm_campaign": utm_campaign,
            "utm_medium": utm_medium,
            "utm_content": utm_content,
            "conversion_raw_info": conversion_raw_info
        },
        "flow_settings": {
            "skip_conversion": SKIP_CONVERSION,
            "skip_orquestration": SKIP_ORQUESTRATION,
            "destination_queue": DESTINATION_QUEUE
        }
    }

    # Recursively clean before append to eliminate any possible nan or non-JSON-compliant values
    conversion_dict = make_json_compliant_dict(conversion_dict)
    conversions.append(conversion_dict)

conversions
# Out:
# [{'lead_data': {'email': {'value': 'fernanda.amaralmello@gmail.com'},
#    'phone': {'raw_phone_input': '5541991635720',
#     'formatted_phone': '+5541991635720',
#     'whatsapp_format': '+554191635720',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5541991635720'},
#    'name': 'Fernanda Damasceno do Amaral Mello'},
#   'conversion_data': {'conversion_date': '2025-12-30T16:58:13.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'ja4j8px',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conseguir um aumento/promoção no meu emprego atual.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'marcosspt2@gmail.com'},
#    'phone': {'raw_phone_input': '5511918831009',
#     'formatted_phone': '+5511918831009',
#     'whatsapp_format': '+5511918831009',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511918831009'},
#    'name': 'Marcos Paulo Mendonça'},
#   'conversion_data': {'conversion_date': '2025-12-30T16:58:32.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'ja4j8YE',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 31 a 34 anos',
#     'current_occupation': 'Empreendedor(a)',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 10.000,00 a R$ 30.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'fabiolamonte@gmail.com'},
#    'phone': {'raw_phone_input': '5531984619327',
#     'formatted_phone': '+5531984619327',
#     'whatsapp_format': '+553184619327',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5531984619327'},
#    'name': 'Fabíola Soares do Monte'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:01:23.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'ja4jAla',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Autônomo',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'rodriguinhogda@gmail.com'},
#    'phone': {'raw_phone_input': '351966675494',
#     'formatted_phone': '351966675494',
#     'whatsapp_format': '351966675494',
#     'isValid': False,
#     'type': 'Invalid',
#     'ddd': None,
#     'ddi': None,
#     'region': None,
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': None,
#     'raw_phone': '351966675494'},
#    'name': 'Rodrigo Lima Corrêa '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:06:30.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Y5B1APv',
#     'country': 'Portugal',
#     'gender': 'Masculino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conquistar um emprego melhor.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'raquellopezsmile@hotmail.com'},
#    'phone': {'raw_phone_input': '5517981485015',
#     'formatted_phone': '+5517981485015',
#     'whatsapp_format': '+5517981485015',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 17,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5517981485015'},
#    'name': 'Raquel Lopes dos Santos '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:07:55.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'ja4jVLx',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'eversmayara@gmail.com'},
#    'phone': {'raw_phone_input': '5542988441785',
#     'formatted_phone': '+5542988441785',
#     'whatsapp_format': '+554288441785',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 42,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5542988441785'},
#    'name': 'Mayara Mendes Evers'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:09:58.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'gDPEo1J',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 18 a 21 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'dessinha.chichico@gmail.com'},
#    'phone': {'raw_phone_input': '201093423556',
#     'formatted_phone': '201093423556',
#     'whatsapp_format': '201093423556',
#     'isValid': False,
#     'type': 'Invalid',
#     'ddd': None,
#     'ddi': None,
#     'region': None,
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': None,
#     'raw_phone': '201093423556'},
#    'name': 'ANDRESSA LIMA DE ALMEIDA'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:18:57.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'lb2xxrp',
#     'country': 'Egito',
#     'gender': 'Feminino',
#     'age_range': 'De 31 a 34 anos',
#     'current_occupation': 'Empreendedor(a)',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'jucineip@uol.com.br'},
#    'phone': {'raw_phone_input': '5541991069200',
#     'formatted_phone': '+5541991069200',
#     'whatsapp_format': '+554191069200',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5541991069200'},
#    'name': 'Jucine Pereira '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:21:50.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'dWGOO4A',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Aposentado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'apteixeira@netcabo.pt'},
#    'phone': {'raw_phone_input': '351932819144',
#     'formatted_phone': '351932819144',
#     'whatsapp_format': '351932819144',
#     'isValid': False,
#     'type': 'Invalid',
#     'ddd': None,
#     'ddi': None,
#     'region': None,
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': None,
#     'raw_phone': '351932819144'},
#    'name': 'Ana Paula Camarinha Teixeira'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:23:11.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '440MMZ5',
#     'country': 'Portugal',
#     'gender': 'Feminino',
#     'age_range': 'De 55 a 64 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 10.000,00 a R$ 30.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'alvarezrb@gmail.com'},
#    'phone': {'raw_phone_input': '5514981441523',
#     'formatted_phone': '+5514981441523',
#     'whatsapp_format': '+5514981441523',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 14,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5514981441523'},
#    'name': 'Rodrigo Basso '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:27:24.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'kdj2Lgo',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'De R$ 10.000,00 a R$ 30.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'cmc.nicolly@gmail.com'},
#    'phone': {'raw_phone_input': '5562999726369',
#     'formatted_phone': '+5562999726369',
#     'whatsapp_format': '+556299726369',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 62,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Goiás',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5562999726369'},
#    'name': 'Nicolly Caldeira de Moura Carmo'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:27:35.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'vG6lRbD',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'elliee764.az@gmail.com'},
#    'phone': {'raw_phone_input': '5528999448810',
#     'formatted_phone': '+5528999448810',
#     'whatsapp_format': '+5528999448810',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 28,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Espirito Santo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5528999448810'},
#    'name': 'Ellen de Aguiar Zardo '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:32:23.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'EkV29Nq',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 15 a 17 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Fazer um intercâmbio.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'paulapacanaro@outlook.com'},
#    'phone': {'raw_phone_input': '5511986144935',
#     'formatted_phone': '+5511986144935',
#     'whatsapp_format': '+5511986144935',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511986144935'},
#    'name': 'Paula Pacanaro'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:41:22.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'ODq6WD7',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 31 a 34 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'alyne_braun@hotmail.com'},
#    'phone': {'raw_phone_input': '19737800466',
#     'formatted_phone': '+5519737800466',
#     'whatsapp_format': '+5519737800466',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 19,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '19737800466'},
#    'name': 'Alyne Braun '},
#   'conversion_data': {'conversion_date': '2025-12-30T17:54:23.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'A7RkPLz',
#     'country': 'Ilhas Virgens dos Estados Unidos',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Autônomo',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'nayla_axel@hotmail.com'},
#    'phone': {'raw_phone_input': '5595991287623',
#     'formatted_phone': '+5595991287623',
#     'whatsapp_format': '+559591287623',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 95,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Roraima',
#     'timezone': ['America/Manaus'],
#     'number_type': 'Mobile',
#     'raw_phone': '5595991287623'},
#    'name': 'Nayla Dias'},
#   'conversion_data': {'conversion_date': '2025-12-30T17:55:11.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'vG6Rj4Q',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'lorrannymendesengcivil@gmail.com'},
#    'phone': {'raw_phone_input': '5521994701316',
#     'formatted_phone': '+5521994701316',
#     'whatsapp_format': '+5521994701316',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 21,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Rio de Janeiro',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5521994701316'},
#    'name': 'Lorranny Vieira Mendes '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:01:43.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'J9jy984',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Avançado.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'wanessa242@gmail.com'},
#    'phone': {'raw_phone_input': '5562992068691',
#     'formatted_phone': '+5562992068691',
#     'whatsapp_format': '+556292068691',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 62,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Goiás',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5562992068691'},
#    'name': 'Wanessa Augusto de Oliveira '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:04:02.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '9q0eqK5',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conquistar um emprego melhor.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'bybyali759@gmail.com'},
#    'phone': {'raw_phone_input': '5511998756730',
#     'formatted_phone': '+5511998756730',
#     'whatsapp_format': '+5511998756730',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511998756730'},
#    'name': 'Edilaine Pinheiro '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:05:42.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'PdQoR9d',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Desempregado(a)',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'cibelleruzky@gmail.com'},
#    'phone': {'raw_phone_input': '5511985838888',
#     'formatted_phone': '+5511985838888',
#     'whatsapp_format': '+5511985838888',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511985838888'},
#    'name': 'CIBELLE FERRAZ '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:10:06.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '5B0NXNQ',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Autônomo',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'luaraujofonseca@outlook.com'},
#    'phone': {'raw_phone_input': '5531987022792',
#     'formatted_phone': '+5531987022792',
#     'whatsapp_format': '+553187022792',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5531987022792'},
#    'name': 'Lucilene Araújo Reis Fonseca '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:13:19.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '0Q04doA',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'battisti_fernando@hotmail.com'},
#    'phone': {'raw_phone_input': '5551993466815',
#     'formatted_phone': '+5551993466815',
#     'whatsapp_format': '+555193466815',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 51,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Rio Grande do Sul',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5551993466815'},
#    'name': 'Fernando Henrique '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:15:12.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'A7RkzRk',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'marcelaserrasoaress@gmail.com'},
#    'phone': {'raw_phone_input': '5531988319734',
#     'formatted_phone': '+5531988319734',
#     'whatsapp_format': '+553188319734',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5531988319734'},
#    'name': 'Marcela Soares e Silva'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:18:25.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '440ZBkk',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'bombacini@utfpr.edu.br'},
#    'phone': {'raw_phone_input': '5545999543263',
#     'formatted_phone': '+5545999543263',
#     'whatsapp_format': '+554599543263',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 45,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5545999543263'},
#    'name': 'Marcos Roberto Bombacini'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:19:19.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'q4Qyajd',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 55 a 64 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'gabrielmoura6662@gmail.com'},
#    'phone': {'raw_phone_input': '5518996487392',
#     'formatted_phone': '+5518996487392',
#     'whatsapp_format': '+5518996487392',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 18,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5518996487392'},
#    'name': 'Gabriel de Moura Pereira '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:20:25.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'xXbGjod',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 18 a 21 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'michelerodrigues_brasil@hotmail.com'},
#    'phone': {'raw_phone_input': '5582988640358',
#     'formatted_phone': '+5582988640358',
#     'whatsapp_format': '+558288640358',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 82,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'Alagoas',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5582988640358'},
#    'name': 'Michele Rodrigues da Silva '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:23:40.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'QK9Ge71',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'aleksia_souza@hotmail.com'},
#    'phone': {'raw_phone_input': '5511977952779',
#     'formatted_phone': '+5511977952779',
#     'whatsapp_format': '+5511977952779',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511977952779'},
#    'name': 'Aleksia Souza'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:29:46.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'XxAjo0V',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'castroisac860@gmail.com'},
#    'phone': {'raw_phone_input': '5511980401417',
#     'formatted_phone': '+5511980401417',
#     'whatsapp_format': '+5511980401417',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Oi',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511980401417'},
#    'name': 'Isac Castro '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:29:47.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Y5B2GW0',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 15 a 17 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 10.000,00 a R$ 30.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'albinoamanda19@gmail.com'},
#    'phone': {'raw_phone_input': '18572475490',
#     'formatted_phone': '+5518572475490',
#     'whatsapp_format': '+5518572475490',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 18,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '18572475490'},
#    'name': 'Amanda Euzebio albino '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:29:53.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'aQJW4YW',
#     'country': 'EUA',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Autônomo',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'mateus.santos07@outlook.com'},
#    'phone': {'raw_phone_input': '5541997251203',
#     'formatted_phone': '+5541997251203',
#     'whatsapp_format': '+554197251203',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5541997251203'},
#    'name': 'Mateus '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:30:45.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '440Z7or',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Fazer um intercâmbio.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'simone.silva1129@gmail.com'},
#    'phone': {'raw_phone_input': '5561999016633',
#     'formatted_phone': '+5561999016633',
#     'whatsapp_format': '+556199016633',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 61,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Distrito Federal',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5561999016633'},
#    'name': 'Simone Silva '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:32:34.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'QK9GRyg',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'berggonsalves10@gmail.com'},
#    'phone': {'raw_phone_input': '79999961525',
#     'formatted_phone': '+5579999961525',
#     'whatsapp_format': '+557999961525',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 79,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'Sergipe',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '79999961525'},
#    'name': 'José Robergson dos Santos Gonçalves '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:36:16.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'NpNz7VW',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'larii.rock@gmail.com'},
#    'phone': {'raw_phone_input': '5515996643293',
#     'formatted_phone': '+5515996643293',
#     'whatsapp_format': '+5515996643293',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 15,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5515996643293'},
#    'name': 'Larissa Telles'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:41:40.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '9q0eQZV',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conseguir um aumento/promoção no meu emprego atual.',
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'natannasantiagoo@gmail.com'},
#    'phone': {'raw_phone_input': '14157978344',
#     'formatted_phone': '+5514157978344',
#     'whatsapp_format': '+5514157978344',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 14,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '14157978344'},
#    'name': 'Natanna Santiago'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:44:43.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#2',
#    'utm_medium': 'email',
#    'utm_content': '⚠️ Inscrição incompleta [Oferta de Ano Novo CDF]',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Zjkxaye',
#     'country': 'EUA',
#     'gender': 'Feminino',
#     'age_range': 'De 31 a 34 anos',
#     'current_occupation': 'Autônomo',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'felipeggoncalves08@gmail.com'},
#    'phone': {'raw_phone_input': '5541987086763',
#     'formatted_phone': '+5541987086763',
#     'whatsapp_format': '+554187086763',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 41,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5541987086763'},
#    'name': 'Felipe Gomes Gonçalves '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:45:25.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Bzov7oQ',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 15 a 17 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Conquistar um emprego melhor.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'contatomarianalora@outlook.com'},
#    'phone': {'raw_phone_input': '5511940111243',
#     'formatted_phone': '+5511940111243',
#     'whatsapp_format': '+5511940111243',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511940111243'},
#    'name': 'Mariana Gimenez '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:48:00.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'MeZ0zEl',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'contatomarianalora@outlook.com'},
#    'phone': {'raw_phone_input': '5511940111243',
#     'formatted_phone': '+5511940111243',
#     'whatsapp_format': '+5511940111243',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511940111243'},
#    'name': 'Mariana Gimenez'},
#   'conversion_data': {'conversion_date': '2025-12-30T18:53:06.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'PdQo5Mb',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'sergiomedeirosfilho@gmail.com'},
#    'phone': {'raw_phone_input': '5583996964042',
#     'formatted_phone': '+5583996964042',
#     'whatsapp_format': '+558396964042',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 83,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Paraiba',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5583996964042'},
#    'name': 'Sérgio Carvalho de Medeiros Filho '},
#   'conversion_data': {'conversion_date': '2025-12-30T18:54:14.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'KY2X6VK',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 18 a 21 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'jayson.araujo@gmail.com'},
#    'phone': {'raw_phone_input': '5591984729953',
#     'formatted_phone': '+5591984729953',
#     'whatsapp_format': '+559184729953',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 91,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Pará',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5591984729953'},
#    'name': 'Rinardo Jayson dos Santos Araújo'},
#   'conversion_data': {'conversion_date': '2025-12-30T19:03:29.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'XxAjeyj',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conquistar um emprego melhor.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
# ...
#     'monthy_income': 'De R$ 5001,00 a R$ 10.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'livia.marim.1301@gmail.com'},
#    'phone': {'raw_phone_input': '12023842881',
#     'formatted_phone': '+5512023842881',
#     'whatsapp_format': '+5512023842881',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 12,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '12023842881'},
#    'name': 'Livia Marim'},
#   'conversion_data': {'conversion_date': '2026-01-04T06:41:04.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '1AQM5Lg',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 22 a 24 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'dalete_keuren@hotmail.com'},
#    'phone': {'raw_phone_input': '12405356699',
#     'formatted_phone': '+5512405356699',
#     'whatsapp_format': '+5512405356699',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 12,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '12405356699'},
#    'name': 'Dalete Keuren Sanches Batista '},
#   'conversion_data': {'conversion_date': '2026-01-04T07:27:43.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Np2LN0N',
#     'country': 'Ilhas Virgens dos Estados Unidos',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empreendedor(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Intermediário.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'bento3a@gmail.com'},
#    'phone': {'raw_phone_input': '5511983302510',
#     'formatted_phone': '+5511983302510',
#     'whatsapp_format': '+5511983302510',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 11,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5511983302510'},
#    'name': 'Milton Bento'},
#   'conversion_data': {'conversion_date': '2026-01-04T07:43:25.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '1AQMQ8O',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Desempregado(a)',
#     'biggest_fluency_desire': 'Dominar a gramática da lingua inglesa.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'avisotto@gmail.com'},
#    'phone': {'raw_phone_input': '5535984264843',
#     'formatted_phone': '+5535984264843',
#     'whatsapp_format': '+553584264843',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 35,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Claro',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5535984264843'},
#    'name': 'Anderson Visotto Lopes'},
#   'conversion_data': {'conversion_date': '2026-01-04T09:29:56.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'GxODexZ',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empreendedor(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'loohrsb@gmail.com'},
#    'phone': {'raw_phone_input': '5531994788132',
#     'formatted_phone': '+5531994788132',
#     'whatsapp_format': '+553194788132',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 31,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Minas Gerais',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5531994788132'},
#    'name': 'LORENA ROBERTA SILVA BARBOSA'},
#   'conversion_data': {'conversion_date': '2026-01-04T10:09:04.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'MejYaKA',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 25 a 30 anos',
#     'current_occupation': 'Empreendedor(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 3001,00 a R$ 5.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'jackristnot@hotmail.com'},
#    'phone': {'raw_phone_input': '5545999839287',
#     'formatted_phone': '+5545999839287',
#     'whatsapp_format': '+554599839287',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 45,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Paraná',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5545999839287'},
#    'name': 'JACKELINE CRISTIANE BALBINOT MUNARETTO'},
#   'conversion_data': {'conversion_date': '2026-01-04T11:09:42.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'WOaY0Ae',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conquistar um emprego melhor.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'ana.azul.1973@gmail.com'},
#    'phone': {'raw_phone_input': '491751414295',
#     'formatted_phone': '491751414295',
#     'whatsapp_format': '491751414295',
#     'isValid': False,
#     'type': 'Invalid',
#     'ddd': None,
#     'ddi': None,
#     'region': None,
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': None,
#     'raw_phone': '491751414295'},
#    'name': 'Ana Rosa De Lima Wettlin '},
#   'conversion_data': {'conversion_date': '2026-01-04T14:18:15.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'BzJDN9R',
#     'country': 'Alemanha',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Sim.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'eliana.freitas2006@gmail.com'},
#    'phone': {'raw_phone_input': '34671489060',
#     'formatted_phone': '+5534671489060',
#     'whatsapp_format': '+5534671489060',
#     'isValid': False,
#     'type': 'Nacional',
#     'ddd': 34,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': '',
#     'timezone': ['Etc/Unknown'],
#     'number_type': 'Unknown',
#     'raw_phone': '34671489060'},
#    'name': 'Eliana Oliveira de Freitas '},
#   'conversion_data': {'conversion_date': '2026-01-04T14:59:03.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#1',
#    'utm_medium': 'email',
#    'utm_content': 'Confirme sua participação na Oferta de Ano Novo CDF',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'gD87alM',
#     'country': 'Espanha',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Conseguir um aumento/promoção no meu emprego atual.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'wldossantos.2805@gmail.com'},
#    'phone': {'raw_phone_input': '5591980668418',
#     'formatted_phone': '+5591980668418',
#     'whatsapp_format': '+559180668418',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 91,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': '',
#     'location': 'Pará',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5591980668418'},
#    'name': 'Walter Lucas Batista dos Santos '},
#   'conversion_data': {'conversion_date': '2026-01-04T15:09:19.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#2',
#    'utm_medium': 'email',
#    'utm_content': '⚠️ Inscrição incompleta [Oferta de Ano Novo CDF]',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Np2JlzQ',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 15 a 17 anos',
#     'current_occupation': 'Estudante',
#     'biggest_fluency_desire': 'Fazer um intercâmbio.',
#     'monthy_income': 'Não tenho nenhuma renda',
#     'english_level': 'Começando do zero.',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'correa_murilo@terra.com.br'},
#    'phone': {'raw_phone_input': '5519996150949',
#     'formatted_phone': '+5519996150949',
#     'whatsapp_format': '+5519996150949',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 19,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'Vivo',
#     'location': 'São Paulo',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5519996150949'},
#    'name': 'Murilo Monteiro Correa'},
#   'conversion_data': {'conversion_date': '2026-01-04T15:11:14.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#2',
#    'utm_medium': 'email',
#    'utm_content': '⚠️ Inscrição incompleta [Oferta de Ano Novo CDF]',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': 'Y57MGdJ',
#     'country': 'Brasil',
#     'gender': 'Masculino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'De R$ 10.000,00 a R$ 30.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'dailacerda@gmail.com'},
#    'phone': {'raw_phone_input': '5548999093150',
#     'formatted_phone': '+5548999093150',
#     'whatsapp_format': '+554899093150',
#     'isValid': True,
#     'type': 'Nacional',
#     'ddd': 48,
#     'ddi': 55,
#     'region': 'BR',
#     'carrier': 'TIM',
#     'location': 'Santa Catarina',
#     'timezone': ['America/Sao_Paulo'],
#     'number_type': 'Mobile',
#     'raw_phone': '5548999093150'},
#    'name': 'Idaiana L Machado'},
#   'conversion_data': {'conversion_date': '2026-01-04T15:12:37.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'ActiveCampaign',
#    'utm_campaign': '[OFAN26] [Onboarding]   E#2',
#    'utm_medium': 'email',
#    'utm_content': '⚠️ Inscrição incompleta [Oferta de Ano Novo CDF]',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '0QqJ8A0',
#     'country': 'Brasil',
#     'gender': 'Feminino',
#     'age_range': 'De 35 a 44 anos',
#     'current_occupation': 'Dona de casa',
#     'biggest_fluency_desire': 'Me comunicar com segurança em viagens internacionais.',
#     'monthy_income': 'Até R$ 1.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  {'lead_data': {'email': {'value': 'sorayagarcez@hotmail.com'},
#    'phone': {'raw_phone_input': '351914040497',
#     'formatted_phone': '351914040497',
#     'whatsapp_format': '351914040497',
#     'isValid': False,
#     'type': 'Invalid',
#     'ddd': None,
#     'ddi': None,
#     'region': None,
#     'carrier': None,
#     'location': None,
#     'timezone': None,
#     'number_type': None,
#     'raw_phone': '351914040497'},
#    'name': 'Soraya Garcez'},
#   'conversion_data': {'conversion_date': '2026-01-04T16:01:39.000Z',
#    'campaign_id': 'lcto-ofan-jan26',
#    'conversion_type_id': '2',
#    'utm_source': 'whatsapp',
#    'utm_campaign': 'lcto-ofan-jan26',
#    'utm_medium': 'direct',
#    'utm_content': 'Onboarding',
#    'conversion_raw_info': {'form_id': 'Y5P1AN',
#     'submission_id': '9qAEEW1',
#     'country': 'Portugal',
#     'gender': 'Feminino',
#     'age_range': 'De 45 a 54 anos',
#     'current_occupation': 'Empregado(a)',
#     'biggest_fluency_desire': 'Morar no exterior.',
#     'monthy_income': 'De R$ 1001,00 a R$ 3.000,00',
#     'english_level': 'Básico',
#     'took_english_course': 'Não.'}},
#   'flow_settings': {'skip_conversion': False,
#    'skip_orquestration': True,
#    'destination_queue': 'S.NORM.PROD.NEW'}},
#  ...]

# %%
import requests
import time
import json
import os

BASE_URL = "https://webhooks.aloud.com.br/data/ce7d3845-3acf-4606-835c-63485eb5fe70"

responses = []

PERSISTENCE_FILE = "imported_leads.json"

# Função auxiliar para obter valor de chave profunda (key_path)
def get_deep_key(d, key_path, default=""):
    """Busca valor em d pelo key_path em formato dot (ex: 'conversion_data.conversion_raw_info.submission_id')"""
    try:
        for key in key_path.split("."):
            d = d[key]
        return d
    except (KeyError, TypeError):
        return default

# Permite selecionar qual chave (via path) será usada para controle de importação
IMPORT_CONTROL_KEY_PATH = "conversion_data.conversion_raw_info.submission_id"

# Carregue os registros persistidos previamente já enviados, se existir
if os.path.exists(PERSISTENCE_FILE):
    with open(PERSISTENCE_FILE, "r", encoding="utf-8") as f:
        imported_keys = set(json.load(f))
else:
    imported_keys = set()

total_to_import = len(conversions)
print(f"Total de registros para importar: {total_to_import}")

for idx, item in enumerate(conversions, start=1):
    import_key = str(get_deep_key(item, IMPORT_CONTROL_KEY_PATH, "")).strip()
    if not import_key:
        print(f"Registro {idx} ignorado: chave de controle '{IMPORT_CONTROL_KEY_PATH}' ausente ou inválida.")
        continue
    if import_key in imported_keys:
        print(f"Registro {idx} já foi importado anteriormente para a chave '{import_key}', ignorando.")
        continue
    
    print(f"Importando registro {idx} de {total_to_import}... (key: {import_key})")
    response = requests.post(BASE_URL, json=item)
    try:
        resp_json = response.json()
    except Exception:
        resp_json = response.text
    responses.append(resp_json)
    
    # Atualize a persistência local imediatamente
    imported_keys.add(import_key)
    with open(PERSISTENCE_FILE, "w", encoding="utf-8") as f:
        json.dump(sorted(list(imported_keys)), f, ensure_ascii=False, indent=2)
# Out:
# Total de registros para importar: 2962
# Registro 1 já foi importado anteriormente para a chave 'ja4j8px', ignorando.
# Registro 2 já foi importado anteriormente para a chave 'ja4j8YE', ignorando.
# Registro 3 já foi importado anteriormente para a chave 'ja4jAla', ignorando.
# Registro 4 já foi importado anteriormente para a chave 'Y5B1APv', ignorando.
# Registro 5 já foi importado anteriormente para a chave 'ja4jVLx', ignorando.
# Registro 6 já foi importado anteriormente para a chave 'gDPEo1J', ignorando.
# Registro 7 já foi importado anteriormente para a chave 'lb2xxrp', ignorando.
# Registro 8 já foi importado anteriormente para a chave 'dWGOO4A', ignorando.
# Registro 9 já foi importado anteriormente para a chave '440MMZ5', ignorando.
# Registro 10 já foi importado anteriormente para a chave 'kdj2Lgo', ignorando.
# Registro 11 já foi importado anteriormente para a chave 'vG6lRbD', ignorando.
# Registro 12 já foi importado anteriormente para a chave 'EkV29Nq', ignorando.
# Registro 13 já foi importado anteriormente para a chave 'ODq6WD7', ignorando.
# Registro 14 já foi importado anteriormente para a chave 'A7RkPLz', ignorando.
# Registro 15 já foi importado anteriormente para a chave 'vG6Rj4Q', ignorando.
# Registro 16 já foi importado anteriormente para a chave 'J9jy984', ignorando.
# Registro 17 já foi importado anteriormente para a chave '9q0eqK5', ignorando.
# Registro 18 já foi importado anteriormente para a chave 'PdQoR9d', ignorando.
# Registro 19 já foi importado anteriormente para a chave '5B0NXNQ', ignorando.
# Registro 20 já foi importado anteriormente para a chave '0Q04doA', ignorando.
# Registro 21 já foi importado anteriormente para a chave 'A7RkzRk', ignorando.
# Registro 22 já foi importado anteriormente para a chave '440ZBkk', ignorando.
# Registro 23 já foi importado anteriormente para a chave 'q4Qyajd', ignorando.
# Registro 24 já foi importado anteriormente para a chave 'xXbGjod', ignorando.
# Registro 25 já foi importado anteriormente para a chave 'QK9Ge71', ignorando.
# Registro 26 já foi importado anteriormente para a chave 'XxAjo0V', ignorando.
# Registro 27 já foi importado anteriormente para a chave 'Y5B2GW0', ignorando.
# Registro 28 já foi importado anteriormente para a chave 'aQJW4YW', ignorando.
# Registro 29 já foi importado anteriormente para a chave '440Z7or', ignorando.
# Registro 30 já foi importado anteriormente para a chave 'QK9GRyg', ignorando.
# Registro 31 já foi importado anteriormente para a chave 'NpNz7VW', ignorando.
# Registro 32 já foi importado anteriormente para a chave '9q0eQZV', ignorando.
# Registro 33 já foi importado anteriormente para a chave 'Zjkxaye', ignorando.
# Registro 34 já foi importado anteriormente para a chave 'Bzov7oQ', ignorando.
# Registro 35 já foi importado anteriormente para a chave 'MeZ0zEl', ignorando.
# Registro 36 já foi importado anteriormente para a chave 'PdQo5Mb', ignorando.
# Registro 37 já foi importado anteriormente para a chave 'KY2X6VK', ignorando.
# Registro 38 já foi importado anteriormente para a chave 'XxAjeyj', ignorando.
# Registro 39 já foi importado anteriormente para a chave 'ODqR04M', ignorando.
# Registro 40 já foi importado anteriormente para a chave 'rj9XExl', ignorando.
# Registro 41 já foi importado anteriormente para a chave 'eqObL2l', ignorando.
# Registro 42 já foi importado anteriormente para a chave 'gDPBLr1', ignorando.
# Registro 43 já foi importado anteriormente para a chave 'vG6R48X', ignorando.
# Registro 44 já foi importado anteriormente para a chave '2Ed2v0g', ignorando.
# Registro 45 já foi importado anteriormente para a chave '680qOYk', ignorando.
# Registro 46 já foi importado anteriormente para a chave 'LZx8MvG', ignorando.
# Registro 47 já foi importado anteriormente para a chave 'gDPBNk1', ignorando.
# Registro 48 já foi importado anteriormente para a chave 'EkVpBdL', ignorando.
# Registro 49 já foi importado anteriormente para a chave 'XxAjOXz', ignorando.
# Registro 50 já foi importado anteriormente para a chave '1A0jDqL', ignorando.
# Registro 51 já foi importado anteriormente para a chave 'xXbGRDv', ignorando.
# Registro 52 já foi importado anteriormente para a chave '0Q04ZeB', ignorando.
# Registro 53 já foi importado anteriormente para a chave 'dWG78jq', ignorando.
# Registro 54 já foi importado anteriormente para a chave 'LZx86el', ignorando.
# Registro 55 já foi importado anteriormente para a chave '440ZzNr', ignorando.
# Registro 56 já foi importado anteriormente para a chave '440ZO7X', ignorando.
# Registro 57 já foi importado anteriormente para a chave 'Y5B29Oq', ignorando.
# Registro 58 já foi importado anteriormente para a chave 'LZx8Oky', ignorando.
# Registro 59 já foi importado anteriormente para a chave 'kdjLzxe', ignorando.
# Registro 60 já foi importado anteriormente para a chave 'D4OLaOq', ignorando.
# Registro 61 já foi importado anteriormente para a chave 'LZx8VoO', ignorando.
# Registro 62 já foi importado anteriormente para a chave 'obNJgY5', ignorando.
# Registro 63 já foi importado anteriormente para a chave 'ja4Kgr1', ignorando.
# Registro 64 já foi importado anteriormente para a chave 'A7RkaXe', ignorando.
# Registro 65 já foi importado anteriormente para a chave 'kdjL1pr', ignorando.
# Registro 66 já foi importado anteriormente para a chave 'EkVprp4', ignorando.
# Registro 67 já foi importado anteriormente para a chave 'EkVpGzr', ignorando.
# Registro 68 já foi importado anteriormente para a chave 'rj9X9a2', ignorando.
# Registro 69 já foi importado anteriormente para a chave 'PdQoQOV', ignorando.
# Registro 70 já foi importado anteriormente para a chave 'pbqgqlZ', ignorando.
# Registro 71 já foi importado anteriormente para a chave 'WOb4a6e', ignorando.
# Registro 72 já foi importado anteriormente para a chave 'dWG7OKz', ignorando.
# Registro 73 já foi importado anteriormente para a chave 'gDPBEo4', ignorando.
# Registro 74 já foi importado anteriormente para a chave 'rj9XXvl', ignorando.
# Registro 75 já foi importado anteriormente para a chave 'rj9XXgM', ignorando.
# Registro 76 já foi importado anteriormente para a chave 'kdjLL2r', ignorando.
# Registro 77 já foi importado anteriormente para a chave 'zxBVP4R', ignorando.
# Registro 78 já foi importado anteriormente para a chave 'pbqaoQq', ignorando.
# Registro 79 já foi importado anteriormente para a chave 'Zjk02bV', ignorando.
# Registro 80 já foi importado anteriormente para a chave 'D4OQzKb', ignorando.
# Registro 81 já foi importado anteriormente para a chave 'zxBlYqE', ignorando.
# Registro 82 já foi importado anteriormente para a chave 'QK9LVLY', ignorando.
# Registro 83 já foi importado anteriormente para a chave 'GxEWdvk', ignorando.
# Registro 84 já foi importado anteriormente para a chave 'KY2bMPA', ignorando.
# Registro 85 já foi importado anteriormente para a chave 'QK9L0Ng', ignorando.
# Registro 86 já foi importado anteriormente para a chave 'QK9Ld1X', ignorando.
# Registro 87 já foi importado anteriormente para a chave 'GxEWL22', ignorando.
# Registro 88 já foi importado anteriormente para a chave '4405vXB', ignorando.
# Registro 89 já foi importado anteriormente para a chave '680ov9o', ignorando.
# Registro 90 já foi importado anteriormente para a chave 'dWGrDEz', ignorando.
# Registro 91 já foi importado anteriormente para a chave 'PdQKXpQ', ignorando.
# Registro 92 já foi importado anteriormente para a chave '2Ed0JoL', ignorando.
# Registro 93 já foi importado anteriormente para a chave 'LZxlJLz', ignorando.
# Registro 94 já foi importado anteriormente para a chave 'VL7gMKj', ignorando.
# Registro 95 já foi importado anteriormente para a chave 'PdQKBGB', ignorando.
# Registro 96 já foi importado anteriormente para a chave 'ja4N9E4', ignorando.
# Registro 97 já foi importado anteriormente para a chave '1A08GQ1', ignorando.
# Registro 98 já foi importado anteriormente para a chave 'obNWKOb', ignorando.
# Registro 99 já foi importado anteriormente para a chave 'QK9LvYX', ignorando.
# Registro 100 já foi importado anteriormente para a chave 'Y5B8JW6', ignorando.
# Registro 101 já foi importado anteriormente para a chave 'NpNkR2B', ignorando.
# Registro 102 já foi importado anteriormente para a chave 'kdjqv1Z', ignorando.
# Registro 103 já foi importado anteriormente para a chave 'kdjqvBe', ignorando.
# Registro 104 já foi importado anteriormente para a chave 'ODqvk2R', ignorando.
# Registro 105 já foi importado anteriormente para a chave '7R0GMQP', ignorando.
# Registro 106 já foi importado anteriormente para a chave '81DOM0x', ignorando.
# Registro 107 já foi importado anteriormente para a chave '0Q0Xap6', ignorando.
# Registro 108 já foi importado anteriormente para a chave 'EkV96zo', ignorando.
# Registro 109 já foi importado anteriormente para a chave '0Q0XkvB', ignorando.
# Registro 110 já foi importado anteriormente para a chave 'XxAXQBY', ignorando.
# Registro 111 já foi importado anteriormente para a chave '0Q0Xkk6', ignorando.
# Registro 112 já foi importado anteriormente para a chave 'obNWzpX', ignorando.
# Registro 113 já foi importado anteriormente para a chave 'dWGrRRo', ignorando.
# Registro 114 já foi importado anteriormente para a chave 'lb2Qg8B', ignorando.
# Registro 115 já foi importado anteriormente para a chave 'yPALGZ6', ignorando.
# Registro 116 já foi importado anteriormente para a chave 'PdQKg91', ignorando.
# Registro 117 já foi importado anteriormente para a chave 'NpNkgMW', ignorando.
# Registro 118 já foi importado anteriormente para a chave 'LZxlyDO', ignorando.
# Registro 119 já foi importado anteriormente para a chave '680o51k', ignorando.
# Registro 120 já foi importado anteriormente para a chave 'WObydKa', ignorando.
# Registro 121 já foi importado anteriormente para a chave 'WObydXL', ignorando.
# Registro 122 já foi importado anteriormente para a chave 'GxEW4p2', ignorando.
# Registro 123 já foi importado anteriormente para a chave '4405y8o', ignorando.
# Registro 124 já foi importado anteriormente para a chave 'ODqv9Ja', ignorando.
# Registro 125 já foi importado anteriormente para a chave 'ODqv99K', ignorando.
# Registro 126 já foi importado anteriormente para a chave 'EkV9E2A', ignorando.
# Registro 127 já foi importado anteriormente para a chave 'RGepaOQ', ignorando.
# Registro 128 já foi importado anteriormente para a chave 'zxBloPk', ignorando.
# Registro 129 já foi importado anteriormente para a chave 'PdQKWO5', ignorando.
# Registro 130 já foi importado anteriormente para a chave 'aQJVPM9', ignorando.
# Registro 131 já foi importado anteriormente para a chave 'Zjk0Lqv', ignorando.
# Registro 132 já foi importado anteriormente para a chave 'eqO48qQ', ignorando.
# Registro 133 já foi importado anteriormente para a chave '81DOYzo', ignorando.
# Registro 134 já foi importado anteriormente para a chave 'ja4NryQ', ignorando.
# Registro 135 já foi importado anteriormente para a chave 'rj97QGv', ignorando.
# Registro 136 já foi importado anteriormente para a chave 'pbqaNME', ignorando.
# Registro 137 já foi importado anteriormente para a chave '7R0G7zZ', ignorando.
# Registro 138 já foi importado anteriormente para a chave 'VL7gW7v', ignorando.
# Registro 139 já foi importado anteriormente para a chave 'xXbK8qJ', ignorando.
# Registro 140 já foi importado anteriormente para a chave 'ODqvMvK', ignorando.
# Registro 141 já foi importado anteriormente para a chave 'aQJVM9W', ignorando.
# Registro 142 já foi importado anteriormente para a chave 'RGep9Vl', ignorando.
# Registro 143 já foi importado anteriormente para a chave 'MeZBxVg', ignorando.
# Registro 144 já foi importado anteriormente para a chave 'VL7g6RJ', ignorando.
# Registro 145 já foi importado anteriormente para a chave '44056YB', ignorando.
# Registro 146 já foi importado anteriormente para a chave 'J9j7PaK', ignorando.
# Registro 147 já foi importado anteriormente para a chave 'obNWJex', ignorando.
# Registro 148 já foi importado anteriormente para a chave 'Zjk0xEB', ignorando.
# Registro 149 já foi importado anteriormente para a chave 'XxAXXLe', ignorando.
# Registro 150 já foi importado anteriormente para a chave 'BzoNN8N', ignorando.
# Registro 151 já foi importado anteriormente para a chave 'ODqvOzM', ignorando.
# Registro 152 já foi importado anteriormente para a chave 'NpNkGYO', ignorando.
# Registro 153 já foi importado anteriormente para a chave 'XxAXZdV', ignorando.
# Registro 154 já foi importado anteriormente para a chave '2Ed0MeA', ignorando.
# Registro 155 já foi importado anteriormente para a chave 'PdQKaJd', ignorando.
# Registro 156 já foi importado anteriormente para a chave '4405WaA', ignorando.
# Registro 157 já foi importado anteriormente para a chave '9q0VLB5', ignorando.
# Registro 158 já foi importado anteriormente para a chave '2Ed0qLp', ignorando.
# Registro 159 já foi importado anteriormente para a chave '9q0bGlQ', ignorando.
# Registro 160 já foi importado anteriormente para a chave 'Y5BNDdB', ignorando.
# Registro 161 já foi importado anteriormente para a chave 'lb2JDXo', ignorando.
# Registro 162 já foi importado anteriormente para a chave 'aQJ7Q0X', ignorando.
# Registro 163 já foi importado anteriormente para a chave '1A0qWXQ', ignorando.
# Registro 164 já foi importado anteriormente para a chave 'RGeEWPl', ignorando.
# Registro 165 já foi importado anteriormente para a chave '440eBpB', ignorando.
# Registro 166 já foi importado anteriormente para a chave 'ZjkqEGo', ignorando.
# Registro 167 já foi importado anteriormente para a chave 'VL72QBl', ignorando.
# Registro 168 já foi importado anteriormente para a chave '2EdQadg', ignorando.
# Registro 169 já foi importado anteriormente para a chave 'rj9zOM5', ignorando.
# Registro 170 já foi importado anteriormente para a chave 'D4Ogp8p', ignorando.
# Registro 171 já foi importado anteriormente para a chave 'GxE8Rrj', ignorando.
# Registro 172 já foi importado anteriormente para a chave 'pbq8D9B', ignorando.
# Registro 173 já foi importado anteriormente para a chave 'yPAVYq4', ignorando.
# Registro 174 já foi importado anteriormente para a chave 'ODqOGqg', ignorando.
# Registro 175 já foi importado anteriormente para a chave 'ja41PdR', ignorando.
# Registro 176 já foi importado anteriormente para a chave 'Zjkq6yv', ignorando.
# Registro 177 já foi importado anteriormente para a chave 'kdjMyEJ', ignorando.
# Registro 178 já foi importado anteriormente para a chave 'yPAV6Yp', ignorando.
# Registro 179 já foi importado anteriormente para a chave 'NpNG6dl', ignorando.
# Registro 180 já foi importado anteriormente para a chave 'QK9PAe7', ignorando.
# Registro 181 já foi importado anteriormente para a chave 'zxBPKe8', ignorando.
# Registro 182 já foi importado anteriormente para a chave 'ja41Bj6', ignorando.
# Registro 183 já foi importado anteriormente para a chave 'EkVy1aA', ignorando.
# Registro 184 já foi importado anteriormente para a chave 'xXbOZ25', ignorando.
# Registro 185 já foi importado anteriormente para a chave '680aRDB', ignorando.
# Registro 186 já foi importado anteriormente para a chave 'yPAVxDd', ignorando.
# Registro 187 já foi importado anteriormente para a chave 'LZxREj2', ignorando.
# Registro 188 já foi importado anteriormente para a chave 'KY2d8kX', ignorando.
# Registro 189 já foi importado anteriormente para a chave 'xXbORd5', ignorando.
# Registro 190 já foi importado anteriormente para a chave 'RGeEjdj', ignorando.
# Registro 191 já foi importado anteriormente para a chave 'WObxQKj', ignorando.
# Registro 192 já foi importado anteriormente para a chave 'Y5BNyPW', ignorando.
# Registro 193 já foi importado anteriormente para a chave '440eDbr', ignorando.
# Registro 194 já foi importado anteriormente para a chave 'LZxRBez', ignorando.
# Registro 195 já foi importado anteriormente para a chave 'ODqOZ2K', ignorando.
# Registro 196 já foi importado anteriormente para a chave '0Q0Nqby', ignorando.
# Registro 197 já foi importado anteriormente para a chave 'aQJ7WNv', ignorando.
# Registro 198 já foi importado anteriormente para a chave 'q4Q06Ok', ignorando.
# Registro 199 já foi importado anteriormente para a chave 'pbqlx6q', ignorando.
# Registro 200 já foi importado anteriormente para a chave 'GxE2pvz', ignorando.
# Registro 201 já foi importado anteriormente para a chave 'WObv8rP', ignorando.
# Registro 202 já foi importado anteriormente para a chave 'Y5BLa9J', ignorando.
# Registro 203 já foi importado anteriormente para a chave 'dWG5x9o', ignorando.
# Registro 204 já foi importado anteriormente para a chave 'BzoPXde', ignorando.
# Registro 205 já foi importado anteriormente para a chave 'KY2qovX', ignorando.
# Registro 206 já foi importado anteriormente para a chave '5B0ykr6', ignorando.
# Registro 207 já foi importado anteriormente para a chave 'D4Ol5v5', ignorando.
# Registro 208 já foi importado anteriormente para a chave 'eqOd2Bx', ignorando.
# Registro 209 já foi importado anteriormente para a chave 'RGe7YX9', ignorando.
# Registro 210 já foi importado anteriormente para a chave '9q0zEkK', ignorando.
# Registro 211 já foi importado anteriormente para a chave 'WObvezv', ignorando.
# Registro 212 já foi importado anteriormente para a chave 'RGe7Z8p', ignorando.
# Registro 213 já foi importado anteriormente para a chave 'obN40v5', ignorando.
# Registro 214 já foi importado anteriormente para a chave 'J9jNXYd', ignorando.
# Registro 215 já foi importado anteriormente para a chave '7R08pB9', ignorando.
# Registro 216 já foi importado anteriormente para a chave 'MeZ9MZl', ignorando.
# Registro 217 já foi importado anteriormente para a chave '440gOxd', ignorando.
# Registro 218 já foi importado anteriormente para a chave 'gDPRpLO', ignorando.
# Registro 219 já foi importado anteriormente para a chave 'kdjVp71', ignorando.
# Registro 220 já foi importado anteriormente para a chave '440gqeX', ignorando.
# Registro 221 já foi importado anteriormente para a chave 'b5R0GVo', ignorando.
# Registro 222 já foi importado anteriormente para a chave '2EdM5Vp', ignorando.
# Registro 223 já foi importado anteriormente para a chave 'kdjVQ7J', ignorando.
# Registro 224 já foi importado anteriormente para a chave 'PdQaW7Q', ignorando.
# Registro 225 já foi importado anteriormente para a chave 'vG6QVl0', ignorando.
# Registro 226 já foi importado anteriormente para a chave 'eqOdGaJ', ignorando.
# Registro 227 já foi importado anteriormente para a chave 'dWG5oZK', ignorando.
# Registro 228 já foi importado anteriormente para a chave '0Q0pYWA', ignorando.
# Registro 229 já foi importado anteriormente para a chave 'q4Q2QR2', ignorando.
# Registro 230 já foi importado anteriormente para a chave 'PdQaQ6d', ignorando.
# Registro 231 já foi importado anteriormente para a chave 'q4Q2QP8', ignorando.
# Registro 232 já foi importado anteriormente para a chave 'Y5BLBKd', ignorando.
# Registro 233 já foi importado anteriormente para a chave 'xXbebbG', ignorando.
# Registro 234 já foi importado anteriormente para a chave 'VL7kWJJ', ignorando.
# Registro 235 já foi importado anteriormente para a chave 'GxE2OYz', ignorando.
# Registro 236 já foi importado anteriormente para a chave 'VL7kOzM', ignorando.
# Registro 237 já foi importado anteriormente para a chave 'rj9xM6R', ignorando.
# Registro 238 já foi importado anteriormente para a chave 'NpNe1LB', ignorando.
# Registro 239 já foi importado anteriormente para a chave 'WObvVav', ignorando.
# Registro 240 já foi importado anteriormente para a chave 'EkV4RBl', ignorando.
# Registro 241 já foi importado anteriormente para a chave '2EdMpj9', ignorando.
# Registro 242 já foi importado anteriormente para a chave 'xXbeAOJ', ignorando.
# Registro 243 já foi importado anteriormente para a chave 'xXbeGjd', ignorando.
# Registro 244 já foi importado anteriormente para a chave '5B0yNZZ', ignorando.
# Registro 245 já foi importado anteriormente para a chave 'VL7krzM', ignorando.
# Registro 246 já foi importado anteriormente para a chave 'QK96Gd8', ignorando.
# Registro 247 já foi importado anteriormente para a chave 'MeZ909X', ignorando.
# Registro 248 já foi importado anteriormente para a chave 'A7RVZdy', ignorando.
# Registro 249 já foi importado anteriormente para a chave '0Q0pNd6', ignorando.
# Registro 250 já foi importado anteriormente para a chave '1A01qvb', ignorando.
# Registro 251 já foi importado anteriormente para a chave 'vG6QoOg', ignorando.
# Registro 252 já foi importado anteriormente para a chave 'obN44px', ignorando.
# Registro 253 já foi importado anteriormente para a chave '2EdMMpA', ignorando.
# Registro 254 já foi importado anteriormente para a chave 'ODqp10Y', ignorando.
# Registro 255 já foi importado anteriormente para a chave 'lb2oDLv', ignorando.
# Registro 256 já foi importado anteriormente para a chave '7R0Bl8Z', ignorando.
# Registro 257 já foi importado anteriormente para a chave 'QK9gKvG', ignorando.
# Registro 258 já foi importado anteriormente para a chave 'Zjk4jez', ignorando.
# Registro 259 já foi importado anteriormente para a chave 'q4Qx4zY', ignorando.
# Registro 260 já foi importado anteriormente para a chave '680b8ze', ignorando.
# Registro 261 já foi importado anteriormente para a chave '7R0BRgL', ignorando.
# Registro 262 já foi importado anteriormente para a chave 'EkVjqqr', ignorando.
# Registro 263 já foi importado anteriormente para a chave 'vG67XAA', ignorando.
# Registro 264 já foi importado anteriormente para a chave 'ODqpQPp', ignorando.
# Registro 265 já foi importado anteriormente para a chave 'GxENeyZ', ignorando.
# Registro 266 já foi importado anteriormente para a chave 'GxENeNQ', ignorando.
# Registro 267 já foi importado anteriormente para a chave 'kdjDldZ', ignorando.
# Registro 268 já foi importado anteriormente para a chave 'vG67MG4', ignorando.
# Registro 269 já foi importado anteriormente para a chave 'obNrEOV', ignorando.
# Registro 270 já foi importado anteriormente para a chave 'obNrErX', ignorando.
# Registro 271 já foi importado anteriormente para a chave 'VL7RjyN', ignorando.
# Registro 272 já foi importado anteriormente para a chave 'xXbkj1E', ignorando.
# Registro 273 já foi importado anteriormente para a chave 'yPAKNrd', ignorando.
# Registro 274 já foi importado anteriormente para a chave 'b5RB9M7', ignorando.
# Registro 275 já foi importado anteriormente para a chave '2EdqB6D', ignorando.
# Registro 276 já foi importado anteriormente para a chave '440WBZY', ignorando.
# Registro 277 já foi importado anteriormente para a chave 'GxEN9xo', ignorando.
# Registro 278 já foi importado anteriormente para a chave '5B06jM6', ignorando.
# Registro 279 já foi importado anteriormente para a chave 'A7Ro25B', ignorando.
# Registro 280 já foi importado anteriormente para a chave '680bK7e', ignorando.
# Registro 281 já foi importado anteriormente para a chave 'WObGRML', ignorando.
# Registro 282 já foi importado anteriormente para a chave '680bKAA', ignorando.
# Registro 283 já foi importado anteriormente para a chave 'ODqpXe7', ignorando.
# Registro 284 já foi importado anteriormente para a chave 'eqO1rGO', ignorando.
# Registro 285 já foi importado anteriormente para a chave '1A0Z40W', ignorando.
# Registro 286 já foi importado anteriormente para a chave 'Zjk4Ok0', ignorando.
# Registro 287 já foi importado anteriormente para a chave 'KY27VRD', ignorando.
# Registro 288 já foi importado anteriormente para a chave 'q4QxRQG', ignorando.
# Registro 289 já foi importado anteriormente para a chave '2EdqK0p', ignorando.
# Registro 290 já foi importado anteriormente para a chave 'NpNKo5b', ignorando.
# Registro 291 já foi importado anteriormente para a chave 'kdjDEvJ', ignorando.
# Registro 292 já foi importado anteriormente para a chave 'ja4dPE6', ignorando.
# Registro 293 já foi importado anteriormente para a chave 'LZxApqJ', ignorando.
# Registro 294 já foi importado anteriormente para a chave '81Dvxgr', ignorando.
# Registro 295 já foi importado anteriormente para a chave '2EdqNPb', ignorando.
# Registro 296 já foi importado anteriormente para a chave 'rj9N6Bl', ignorando.
# Registro 297 já foi importado anteriormente para a chave 'ODqpz5K', ignorando.
# Registro 298 já foi importado anteriormente para a chave 'dWGL66y', ignorando.
# Registro 299 já foi importado anteriormente para a chave 'RGeX029', ignorando.
# Registro 300 já foi importado anteriormente para a chave 'obNrA9O', ignorando.
# Registro 301 já foi importado anteriormente para a chave 'eqO1B9o', ignorando.
# Registro 302 já foi importado anteriormente para a chave '9q0LdRK', ignorando.
# Registro 303 já foi importado anteriormente para a chave 'NpNKVqN', ignorando.
# Registro 304 já foi importado anteriormente para a chave 'KY27oVg', ignorando.
# Registro 305 já foi importado anteriormente para a chave 'A7RoJLe', ignorando.
# Registro 306 já foi importado anteriormente para a chave 'Zjk4VRy', ignorando.
# Registro 307 já foi importado anteriormente para a chave 'XxAVG1O', ignorando.
# Registro 308 já foi importado anteriormente para a chave 'xXbkQ1k', ignorando.
# Registro 309 já foi importado anteriormente para a chave 'dWGLAyK', ignorando.
# Registro 310 já foi importado anteriormente para a chave '440WkMX', ignorando.
# Registro 311 já foi importado anteriormente para a chave 'eqO1EEx', ignorando.
# Registro 312 já foi importado anteriormente para a chave 'ODqpLxp', ignorando.
# Registro 313 já foi importado anteriormente para a chave 'pbqjWBq', ignorando.
# Registro 314 já foi importado anteriormente para a chave '680bvxe', ignorando.
# Registro 315 já foi importado anteriormente para a chave 'A7RoqYe', ignorando.
# Registro 316 já foi importado anteriormente para a chave 'lb2o0vv', ignorando.
# Registro 317 já foi importado anteriormente para a chave '0Q02bzZ', ignorando.
# Registro 318 já foi importado anteriormente para a chave '9q0LRgK', ignorando.
# Registro 319 já foi importado anteriormente para a chave 'GxENQoe', ignorando.
# Registro 320 já foi importado anteriormente para a chave 'GxENQ4j', ignorando.
# Registro 321 já foi importado anteriormente para a chave 'RGeXVX4', ignorando.
# Registro 322 já foi importado anteriormente para a chave 'yPAK1Pd', ignorando.
# Registro 323 já foi importado anteriormente para a chave 'PdQMrYb', ignorando.
# Registro 324 já foi importado anteriormente para a chave 'b5RBAPZ', ignorando.
# Registro 325 já foi importado anteriormente para a chave 'Zjk4Wo0', ignorando.
# Registro 326 já foi importado anteriormente para a chave 'MeZkPz0', ignorando.
# Registro 327 já foi importado anteriormente para a chave '7R0Bjk6', ignorando.
# Registro 328 já foi importado anteriormente para a chave 'gDPypE1', ignorando.
# Registro 329 já foi importado anteriormente para a chave '9q0LyMG', ignorando.
# Registro 330 já foi importado anteriormente para a chave 'xXbkLoG', ignorando.
# Registro 331 já foi importado anteriormente para a chave '2EdqYLp', ignorando.
# Registro 332 já foi importado anteriormente para a chave 'ODqpZeY', ignorando.
# Registro 333 já foi importado anteriormente para a chave 'eqO1G8k', ignorando.
# Registro 334 já foi importado anteriormente para a chave '1A0Z0pM', ignorando.
# Registro 335 já foi importado anteriormente para a chave 'gDPyPOK', ignorando.
# Registro 336 já foi importado anteriormente para a chave 'BzoOoq1', ignorando.
# Registro 337 já foi importado anteriormente para a chave '5B06ajP', ignorando.
# Registro 338 já foi importado anteriormente para a chave 'KY27r7V', ignorando.
# Registro 339 já foi importado anteriormente para a chave 'obNrPGb', ignorando.
# Registro 340 já foi importado anteriormente para a chave '2EdqWxV', ignorando.
# Registro 341 já foi importado anteriormente para a chave 'Zjk4M0e', ignorando.
# Registro 342 já foi importado anteriormente para a chave 'dWGL7aA', ignorando.
# Registro 343 já foi importado anteriormente para a chave 'dWGLrYA', ignorando.
# Registro 344 já foi importado anteriormente para a chave '680badJ', ignorando.
# Registro 345 já foi importado anteriormente para a chave 'zxBpPgZ', ignorando.
# Registro 346 já foi importado anteriormente para a chave '7R0BBpR', ignorando.
# Registro 347 já foi importado anteriormente para a chave 'PdZjjdB', ignorando.
# Registro 348 já foi importado anteriormente para a chave 'yP8ZZod', ignorando.
# Registro 349 já foi importado anteriormente para a chave '686JJoO', ignorando.
# Registro 350 já foi importado anteriormente para a chave '81boNGz', ignorando.
# Registro 351 já foi importado anteriormente para a chave '2E98a0V', ignorando.
# Registro 352 já foi importado anteriormente para a chave '81boL9P', ignorando.
# Registro 353 já foi importado anteriormente para a chave 'VLWEzzE', ignorando.
# Registro 354 já foi importado anteriormente para a chave '2E98KKA', ignorando.
# Registro 355 já foi importado anteriormente para a chave 'KYrQVvV', ignorando.
# Registro 356 já foi importado anteriormente para a chave 'D4R27jE', ignorando.
# Registro 357 já foi importado anteriormente para a chave 'q48ZVaG', ignorando.
# Registro 358 já foi importado anteriormente para a chave '81boxaO', ignorando.
# Registro 359 já foi importado anteriormente para a chave 'rj8yAjX', ignorando.
# Registro 360 já foi importado anteriormente para a chave 'ja8DQpQ', ignorando.
# Registro 361 já foi importado anteriormente para a chave 'MejKzgl', ignorando.
# Registro 362 já foi importado anteriormente para a chave 'pbYxK1y', ignorando.
# Registro 363 já foi importado anteriormente para a chave '0QqrxyP', ignorando.
# Registro 364 já foi importado anteriormente para a chave 'yP8Z6Ox', ignorando.
# Registro 365 já foi importado anteriormente para a chave 'A7MPd1D', ignorando.
# Registro 366 já foi importado anteriormente para a chave 'RGqKzrJ', ignorando.
# Registro 367 já foi importado anteriormente para a chave 'PdZjEde', ignorando.
# Registro 368 já foi importado anteriormente para a chave '686JkKB', ignorando.
# Registro 369 já foi importado anteriormente para a chave 'lb8DAAp', ignorando.
# Registro 370 já foi importado anteriormente para a chave 'VLWElYl', ignorando.
# Registro 371 já foi importado anteriormente para a chave 'ob86BKb', ignorando.
# Registro 372 já foi importado anteriormente para a chave 'J9EKRoK', ignorando.
# Registro 373 já foi importado anteriormente para a chave '44lXkRO', ignorando.
# Registro 374 já foi importado anteriormente para a chave '2E98r7g', ignorando.
# Registro 375 já foi importado anteriormente para a chave 'PdZj041', ignorando.
# Registro 376 já foi importado anteriormente para a chave 'kd8aZq6', ignorando.
# Registro 377 já foi importado anteriormente para a chave '1AQPMX4', ignorando.
# Registro 378 já foi importado anteriormente para a chave '81bo8dr', ignorando.
# Registro 379 já foi importado anteriormente para a chave 'Y57DYoJ', ignorando.
# Registro 380 já foi importado anteriormente para a chave 'WOa9YLe', ignorando.
# Registro 381 já foi importado anteriormente para a chave 'VLWEM26', ignorando.
# Registro 382 já foi importado anteriormente para a chave 'VLWE1Pg', ignorando.
# Registro 383 já foi importado anteriormente para a chave 'WOa9pQe', ignorando.
# Registro 384 já foi importado anteriormente para a chave '2E98x5D', ignorando.
# Registro 385 já foi importado anteriormente para a chave 'VLWE1ag', ignorando.
# Registro 386 já foi importado anteriormente para a chave 'A7MPbXk', ignorando.
# Registro 387 já foi importado anteriormente para a chave 'KYrQBj7', ignorando.
# Registro 388 já foi importado anteriormente para a chave 'GxOvoeQ', ignorando.
# Registro 389 já foi importado anteriormente para a chave 'Xx6lRJz', ignorando.
# Registro 390 já foi importado anteriormente para a chave 'q48ZYkd', ignorando.
# Registro 391 já foi importado anteriormente para a chave 'Zjb5Gev', ignorando.
# Registro 392 já foi importado anteriormente para a chave 'J9EKVxX', ignorando.
# Registro 393 já foi importado anteriormente para a chave 'BzJ48X1', ignorando.
# Registro 394 já foi importado anteriormente para a chave 'QKN28l1', ignorando.
# Registro 395 já foi importado anteriormente para a chave 'VLWEvM6', ignorando.
# Registro 396 já foi importado anteriormente para a chave 'EkozvA4', ignorando.
# Registro 397 já foi importado anteriormente para a chave '81boR1k', ignorando.
# Registro 398 já foi importado anteriormente para a chave 'vG8jdM4', ignorando.
# Registro 399 já foi importado anteriormente para a chave 'ja8DkB4', ignorando.
# Registro 400 já foi importado anteriormente para a chave '686Jpxk', ignorando.
# Registro 401 já foi importado anteriormente para a chave 'VLWE4kv', ignorando.
# Registro 402 já foi importado anteriormente para a chave 'ODx1kLY', ignorando.
# Registro 403 já foi importado anteriormente para a chave '5BaKMOM', ignorando.
# Registro 404 já foi importado anteriormente para a chave 'kd8azd1', ignorando.
# Registro 405 já foi importado anteriormente para a chave '2E98o0M', ignorando.
# Registro 406 já foi importado anteriormente para a chave 'BzJ49XN', ignorando.
# Registro 407 já foi importado anteriormente para a chave 'Y57De4W', ignorando.
# Registro 408 já foi importado anteriormente para a chave 'aQpNyWb', ignorando.
# Registro 409 já foi importado anteriormente para a chave 'Y57DgLB', ignorando.
# Registro 410 já foi importado anteriormente para a chave 'J9EKY0z', ignorando.
# Registro 411 já foi importado anteriormente para a chave 'LZ41yBG', ignorando.
# Registro 412 já foi importado anteriormente para a chave '81boyeY', ignorando.
# Registro 413 já foi importado anteriormente para a chave 'rj8y17L', ignorando.
# Registro 414 já foi importado anteriormente para a chave 'Y57DKev', ignorando.
# Registro 415 já foi importado anteriormente para a chave 'MejKQoX', ignorando.
# Registro 416 já foi importado anteriormente para a chave 'Y57DbJJ', ignorando.
# Registro 417 já foi importado anteriormente para a chave 'J9EKrbY', ignorando.
# Registro 418 já foi importado anteriormente para a chave 'ob86NV5', ignorando.
# Registro 419 já foi importado anteriormente para a chave 'q48Z8bY', ignorando.
# Registro 420 já foi importado anteriormente para a chave 'EkozoJo', ignorando.
# Registro 421 já foi importado anteriormente para a chave 'PdZjqV1', ignorando.
# Registro 422 já foi importado anteriormente para a chave 'lb8DGgv', ignorando.
# Registro 423 já foi importado anteriormente para a chave 'D4R2Qkj', ignorando.
# Registro 424 já foi importado anteriormente para a chave 'Ekozyq4', ignorando.
# Registro 425 já foi importado anteriormente para a chave 'Ekoz4Al', ignorando.
# Registro 426 já foi importado anteriormente para a chave 'VLWERaj', ignorando.
# Registro 427 já foi importado anteriormente para a chave '44lXWYr', ignorando.
# Registro 428 já foi importado anteriormente para a chave '0QqQrjj', ignorando.
# Registro 429 já foi importado anteriormente para a chave 'q484aLd', ignorando.
# Registro 430 já foi importado anteriormente para a chave 'ja8aoEQ', ignorando.
# Registro 431 já foi importado anteriormente para a chave 'MejeMEM', ignorando.
# Registro 432 já foi importado anteriormente para a chave 'rj8jgDl', ignorando.
# Registro 433 já foi importado anteriormente para a chave 'A7M7N8B', ignorando.
# Registro 434 já foi importado anteriormente para a chave 'rj8jQrv', ignorando.
# Registro 435 já foi importado anteriormente para a chave 'ja8aAEJ', ignorando.
# Registro 436 já foi importado anteriormente para a chave 'aQpQWGE', ignorando.
# Registro 437 já foi importado anteriormente para a chave 'WOaOx7k', ignorando.
# Registro 438 já foi importado anteriormente para a chave 'rj8jxyv', ignorando.
# Registro 439 já foi importado anteriormente para a chave 'q484xZ9', ignorando.
# Registro 440 já foi importado anteriormente para a chave '81b1vKA', ignorando.
# Registro 441 já foi importado anteriormente para a chave 'PdZRjWB', ignorando.
# Registro 442 já foi importado anteriormente para a chave '2E9jE9e', ignorando.
# Registro 443 já foi importado anteriormente para a chave 'BzJEzNQ', ignorando.
# Registro 444 já foi importado anteriormente para a chave 'aQpOO99', ignorando.
# Registro 445 já foi importado anteriormente para a chave 'J9E1dQd', ignorando.
# Registro 446 já foi importado anteriormente para a chave 'Mej1a5l', ignorando.
# Registro 447 já foi importado anteriormente para a chave 'BzJEx9Q', ignorando.
# Registro 448 já foi importado anteriormente para a chave 'eqg5ap0', ignorando.
# Registro 449 já foi importado anteriormente para a chave 'dWJbxar', ignorando.
# Registro 450 já foi importado anteriormente para a chave 'kd8bAMj', ignorando.
# Registro 451 já foi importado anteriormente para a chave 'GxOeLLL', ignorando.
# Registro 452 já foi importado anteriormente para a chave 'ob89oLb', ignorando.
# Registro 453 já foi importado anteriormente para a chave 'A7Mrq5z', ignorando.
# Registro 454 já foi importado anteriormente para a chave 'EkoqBBX', ignorando.
# Registro 455 já foi importado anteriormente para a chave 'LZ4Dvzv', ignorando.
# Registro 456 já foi importado anteriormente para a chave '5BaX8xd', ignorando.
# Registro 457 já foi importado anteriormente para a chave '0QqV1M0', ignorando.
# Registro 458 já foi importado anteriormente para a chave 'PdZRvgV', ignorando.
# Registro 459 já foi importado anteriormente para a chave 'dWJb8gV', ignorando.
# Registro 460 já foi importado anteriormente para a chave 'VLWpbdj', ignorando.
# Registro 461 já foi importado anteriormente para a chave 'LZ4Dk7O', ignorando.
# Registro 462 já foi importado anteriormente para a chave 'rj8DvKX', ignorando.
# Registro 463 já foi importado anteriormente para a chave 'eqg5v2x', ignorando.
# Registro 464 já foi importado anteriormente para a chave '2E9jo9p', ignorando.
# Registro 465 já foi importado anteriormente para a chave 'lb8azoX', ignorando.
# Registro 466 já foi importado anteriormente para a chave 'ja8eEQa', ignorando.
# Registro 467 já foi importado anteriormente para a chave 'gD8bOV4', ignorando.
# Registro 468 já foi importado anteriormente para a chave '44laq85', ignorando.
# Registro 469 já foi importado anteriormente para a chave '0QqVlDN', ignorando.
# Registro 470 já foi importado anteriormente para a chave 'ODxQgyp', ignorando.
# Registro 471 já foi importado anteriormente para a chave 'PdZRgqx', ignorando.
# Registro 472 já foi importado anteriormente para a chave 'gD8brel', ignorando.
# Registro 473 já foi importado anteriormente para a chave '7R7X5xL', ignorando.
# Registro 474 já foi importado anteriormente para a chave 'b51ZGJ2', ignorando.
# Registro 475 já foi importado anteriormente para a chave '0QqVyYy', ignorando.
# Registro 476 já foi importado anteriormente para a chave 'b51ZE62', ignorando.
# Registro 477 já foi importado anteriormente para a chave '5BaXgMP', ignorando.
# Registro 478 já foi importado anteriormente para a chave 'xX8VLOy', ignorando.
# Registro 479 já foi importado anteriormente para a chave 'ODxQKXA', ignorando.
# Registro 480 já foi importado anteriormente para a chave 'KYrpAk7', ignorando.
# Registro 481 já foi importado anteriormente para a chave 'KYrpAXX', ignorando.
# Registro 482 já foi importado anteriormente para a chave 'A7MrRDW', ignorando.
# Registro 483 já foi importado anteriormente para a chave 'BzJEoee', ignorando.
# Registro 484 já foi importado anteriormente para a chave 'gD8bPod', ignorando.
# Registro 485 já foi importado anteriormente para a chave 'ob89NJX', ignorando.
# Registro 486 já foi importado anteriormente para a chave 'PdZRQad', ignorando.
# Registro 487 já foi importado anteriormente para a chave 'q4858Qg', ignorando.
# Registro 488 já foi importado anteriormente para a chave '0QqVRAZ', ignorando.
# Registro 489 já foi importado anteriormente para a chave 'ja8eVxY', ignorando.
# Registro 490 já foi importado anteriormente para a chave 'KYrpj9z', ignorando.
# Registro 491 já foi importado anteriormente para a chave 'rj8DZ7X', ignorando.
# Registro 492 já foi importado anteriormente para a chave 'RGqWNjK', ignorando.
# Registro 493 já foi importado anteriormente para a chave 'GxOeG4k', ignorando.
# Registro 494 já foi importado anteriormente para a chave 'GxOeGOp', ignorando.
# Registro 495 já foi importado anteriormente para a chave 'RGqWAbp', ignorando.
# Registro 496 já foi importado anteriormente para a chave '686Dgp5', ignorando.
# Registro 497 já foi importado anteriormente para a chave 'ob89qzM', ignorando.
# Registro 498 já foi importado anteriormente para a chave 'LZ4D8WJ', ignorando.
# Registro 499 já foi importado anteriormente para a chave 'GxOeWKj', ignorando.
# Registro 500 já foi importado anteriormente para a chave 'RGqWpAQ', ignorando.
# Registro 501 já foi importado anteriormente para a chave 'ja8e1yR', ignorando.
# Registro 502 já foi importado anteriormente para a chave 'b51ZbA1', ignorando.
# Registro 503 já foi importado anteriormente para a chave 'ODxQW9a', ignorando.
# Registro 504 já foi importado anteriormente para a chave 'ODxQpDp', ignorando.
# Registro 505 já foi importado anteriormente para a chave 'ob89rox', ignorando.
# Registro 506 já foi importado anteriormente para a chave '7R7XBz6', ignorando.
# Registro 507 já foi importado anteriormente para a chave 'Zjb8joo', ignorando.
# Registro 508 já foi importado anteriormente para a chave '2E9XXBg', ignorando.
# Registro 509 já foi importado anteriormente para a chave 'VLWGG1J', ignorando.
# Registro 510 já foi importado anteriormente para a chave '81bqzQo', ignorando.
# Registro 511 já foi importado anteriormente para a chave 'xX8rjdk', ignorando.
# Registro 512 já foi importado anteriormente para a chave 'Zjb8oy0', ignorando.
# Registro 513 já foi importado anteriormente para a chave 'MejXNvl', ignorando.
# Registro 514 já foi importado anteriormente para a chave 'eqgMQYl', ignorando.
# Registro 515 já foi importado anteriormente para a chave 'ja8Z6rE', ignorando.
# Registro 516 já foi importado anteriormente para a chave 'xX8rDkJ', ignorando.
# Registro 517 já foi importado anteriormente para a chave 'VLWGzLl', ignorando.
# Registro 518 já foi importado anteriormente para a chave 'ja8Zl9x', ignorando.
# Registro 519 já foi importado anteriormente para a chave 'kd8lNxd', ignorando.
# Registro 520 já foi importado anteriormente para a chave 'zx8jYE1', ignorando.
# Registro 521 já foi importado anteriormente para a chave 'Xx6L0Jd', ignorando.
# Registro 522 já foi importado anteriormente para a chave 'kd8l6PJ', ignorando.
# Registro 523 já foi importado anteriormente para a chave '0Qqd6pA', ignorando.
# Registro 524 já foi importado anteriormente para a chave 'VLWGZG6', ignorando.
# Registro 525 já foi importado anteriormente para a chave 'b51qOgL', ignorando.
# Registro 526 já foi importado anteriormente para a chave '686LR15', ignorando.
# Registro 527 já foi importado anteriormente para a chave 'ODxaLM8', ignorando.
# Registro 528 já foi importado anteriormente para a chave '1AQXvNO', ignorando.
# Registro 529 já foi importado anteriormente para a chave 'EkoKJAo', ignorando.
# Registro 530 já foi importado anteriormente para a chave '81bqP5Y', ignorando.
# Registro 531 já foi importado anteriormente para a chave 'LZ49EeG', ignorando.
# Registro 532 já foi importado anteriormente para a chave 'PdZp8Oe', ignorando.
# Registro 533 já foi importado anteriormente para a chave 'zx8jWZa', ignorando.
# Registro 534 já foi importado anteriormente para a chave 'D4RB0Qq', ignorando.
# Registro 535 já foi importado anteriormente para a chave 'aQp9KrB', ignorando.
# Registro 536 já foi importado anteriormente para a chave '5BabeGN', ignorando.
# Registro 537 já foi importado anteriormente para a chave 'Np2rbG0', ignorando.
# Registro 538 já foi importado anteriormente para a chave '0QqdDEZ', ignorando.
# Registro 539 já foi importado anteriormente para a chave 'QKN1kRX', ignorando.
# Registro 540 já foi importado anteriormente para a chave 'VLWGDJy', ignorando.
# Registro 541 já foi importado anteriormente para a chave 'D4RBMAj', ignorando.
# Registro 542 já foi importado anteriormente para a chave 'Xx6Lzbg', ignorando.
# Registro 543 já foi importado anteriormente para a chave 'ODxakNR', ignorando.
# Registro 544 já foi importado anteriormente para a chave '0QqdkyQ', ignorando.
# Registro 545 já foi importado anteriormente para a chave 'VLWGNa6', ignorando.
# Registro 546 já foi importado anteriormente para a chave 'KYrzRLD', ignorando.
# Registro 547 já foi importado anteriormente para a chave 'KYrzRDg', ignorando.
# Registro 548 já foi importado anteriormente para a chave 'PdZpPr5', ignorando.
# Registro 549 já foi importado anteriormente para a chave '686LVbY', ignorando.
# Registro 550 já foi importado anteriormente para a chave 'yP8Mg4B', ignorando.
# Registro 551 já foi importado anteriormente para a chave 'vG8MgL8', ignorando.
# Registro 552 já foi importado anteriormente para a chave '1AQXOGb', ignorando.
# Registro 553 já foi importado anteriormente para a chave 'pbYr5qb', ignorando.
# Registro 554 já foi importado anteriormente para a chave 'GxO6go2', ignorando.
# Registro 555 já foi importado anteriormente para a chave '9qABap4', ignorando.
# Registro 556 já foi importado anteriormente para a chave '686L9W5', ignorando.
# Registro 557 já foi importado anteriormente para a chave 'KYrzgOD', ignorando.
# Registro 558 já foi importado anteriormente para a chave 'D4RBYjq', ignorando.
# Registro 559 já foi importado anteriormente para a chave 'ob8EQE5', ignorando.
# Registro 560 já foi importado anteriormente para a chave '686L5bP', ignorando.
# Registro 561 já foi importado anteriormente para a chave 'q48LM52', ignorando.
# Registro 562 já foi importado anteriormente para a chave '7R7qgD9', ignorando.
# Registro 563 já foi importado anteriormente para a chave '81bqgkY', ignorando.
# Registro 564 já foi importado anteriormente para a chave 'Y57PKeJ', ignorando.
# Registro 565 já foi importado anteriormente para a chave 'ODxaeK7', ignorando.
# Registro 566 já foi importado anteriormente para a chave 'J9EqZrd', ignorando.
# Registro 567 já foi importado anteriormente para a chave 'Y57PK80', ignorando.
# Registro 568 já foi importado anteriormente para a chave 'ob8EYYx', ignorando.
# Registro 569 já foi importado anteriormente para a chave 'eqgMOQE', ignorando.
# Registro 570 já foi importado anteriormente para a chave 'EkoKoA4', ignorando.
# Registro 571 já foi importado anteriormente para a chave '0Qqdqly', ignorando.
# Registro 572 já foi importado anteriormente para a chave 'Xx6L6yj', ignorando.
# Registro 573 já foi importado anteriormente para a chave '44lQlZo', ignorando.
# Registro 574 já foi importado anteriormente para a chave 'EkoK7W4', ignorando.
# Registro 575 já foi importado anteriormente para a chave 'Y57PlV0', ignorando.
# Registro 576 já foi importado anteriormente para a chave 'KYrzKOg', ignorando.
# Registro 577 já foi importado anteriormente para a chave '0QqdWxB', ignorando.
# Registro 578 já foi importado anteriormente para a chave 'VLWG69v', ignorando.
# Registro 579 já foi importado anteriormente para a chave '1AQXaQ1', ignorando.
# Registro 580 já foi importado anteriormente para a chave 'lb8BG7N', ignorando.
# Registro 581 já foi importado anteriormente para a chave 'yP8MQqx', ignorando.
# Registro 582 já foi importado anteriormente para a chave 'vG8MZdv', ignorando.
# Registro 583 já foi importado anteriormente para a chave 'A7Mzgyk', ignorando.
# Registro 584 já foi importado anteriormente para a chave 'WOa2WkQ', ignorando.
# Registro 585 já foi importado anteriormente para a chave 'WOa2WXQ', ignorando.
# Registro 586 já foi importado anteriormente para a chave 'aQp9L1W', ignorando.
# Registro 587 já foi importado anteriormente para a chave '81bqXZA', ignorando.
# Registro 588 já foi importado anteriormente para a chave 'EkoK2D2', ignorando.
# Registro 589 já foi importado anteriormente para a chave 'Zjb8xje', ignorando.
# Registro 590 já foi importado anteriormente para a chave 'ob8EJRP', ignorando.
# Registro 591 já foi importado anteriormente para a chave '0Qqd46N', ignorando.
# Registro 592 já foi importado anteriormente para a chave 'zx8jVo0', ignorando.
# Registro 593 já foi importado anteriormente para a chave '44lQ54d', ignorando.
# Registro 594 já foi importado anteriormente para a chave '7R7qGR6', ignorando.
# Registro 595 já foi importado anteriormente para a chave 'GxO6WX2', ignorando.
# Registro 596 já foi importado anteriormente para a chave 'aQp97aq', ignorando.
# Registro 597 já foi importado anteriormente para a chave 'Np2rGZ0', ignorando.
# Registro 598 já foi importado anteriormente para a chave 'Np2rKd0', ignorando.
# Registro 599 já foi importado anteriormente para a chave '686Lb4Y', ignorando.
# Registro 600 já foi importado anteriormente para a chave 'kd8lDBM', ignorando.
# Registro 601 já foi importado anteriormente para a chave 'gD8ayod', ignorando.
# Registro 602 já foi importado anteriormente para a chave 'ja8bDQ4', ignorando.
# Registro 603 já foi importado anteriormente para a chave 'xX8jx9G', ignorando.
# Registro 604 já foi importado anteriormente para a chave 'xX8jXlo', ignorando.
# Registro 605 já foi importado anteriormente para a chave 'GxOKx4z', ignorando.
# Registro 606 já foi importado anteriormente para a chave '686e8bk', ignorando.
# Registro 607 já foi importado anteriormente para a chave 'aQpeOOq', ignorando.
# Registro 608 já foi importado anteriormente para a chave 'D4RKqOj', ignorando.
# ...
# Importando registro 2718 de 2962... (key: dWele6z)
# Importando registro 2719 de 2962... (key: QKldlAA)
# Importando registro 2720 de 2962... (key: obLoLYV)
# Importando registro 2721 de 2962... (key: 68EREao)
# Importando registro 2722 de 2962... (key: 2EGLGqM)
# Importando registro 2723 de 2962... (key: 68ERBJN)
# Importando registro 2724 de 2962... (key: rjMVZoN)
# Importando registro 2725 de 2962... (key: dWely4d)
# Importando registro 2726 de 2962... (key: kdB5P4e)
# Importando registro 2727 de 2962... (key: QKldQ97)
# Importando registro 2728 de 2962... (key: 2EGLWBg)
# Importando registro 2729 de 2962... (key: XxPEaNV)
# Importando registro 2730 de 2962... (key: PdJlxJB)
# Importando registro 2731 de 2962... (key: obLoqEX)
# Importando registro 2732 de 2962... (key: zx5ZkKg)
# Importando registro 2733 de 2962... (key: Np1LaYO)
# Importando registro 2734 de 2962... (key: b5QLor1)
# Importando registro 2735 de 2962... (key: dWelO8o)
# Importando registro 2736 de 2962... (key: eqWLVv0)
# Importando registro 2737 de 2962... (key: xX52ABG)
# Importando registro 2738 de 2962... (key: obLoWDx)
# Importando registro 2739 de 2962... (key: VLOVgyM)
# Importando registro 2740 de 2962... (key: 44VL5yY)
# Importando registro 2741 de 2962... (key: RGyRp6j)
# Importando registro 2742 de 2962... (key: 0QRLXqN)
# Importando registro 2743 de 2962... (key: lbkLJ6o)
# Importando registro 2744 de 2962... (key: ZjrlqQv)
# Importando registro 2745 de 2962... (key: Ek7LyAL)
# Importando registro 2746 de 2962... (key: 1AoMqyb)
# Importando registro 2747 de 2962... (key: 0QRLNKy)
# Importando registro 2748 de 2962... (key: obLo4KP)
# Importando registro 2749 de 2962... (key: WOVPvKj)
# Importando registro 2750 de 2962... (key: Ek7L4NX)
# Importando registro 2751 de 2962... (key: 0QRLpk6)
# Importando registro 2752 de 2962... (key: 1AoM1xM)
# Importando registro 2753 de 2962... (key: kdB5VQj)
# Importando registro 2754 de 2962... (key: PdJlMjV)
# Importando registro 2755 de 2962... (key: 0QRL260)
# Importando registro 2756 de 2962... (key: RGyRXv4)
# Importando registro 2757 de 2962... (key: KYKL7Z7)
# Importando registro 2758 de 2962... (key: QKldgap)
# Importando registro 2759 de 2962... (key: 1AovPrW)
# Importando registro 2760 de 2962... (key: GxADvBz)
# Importando registro 2761 de 2962... (key: D46D2xX)
# Importando registro 2762 de 2962... (key: vG5Lj6v)
# Importando registro 2763 de 2962... (key: rjMLjvL)
# Importando registro 2764 de 2962... (key: eqW2qzo)
# Importando registro 2765 de 2962... (key: KYKDYd7)
# Importando registro 2766 de 2962... (key: zx5JEqg)
# Importando registro 2767 de 2962... (key: PdJYRlB)
# Importando registro 2768 de 2962... (key: WOVYJQJ)
# Importando registro 2769 de 2962... (key: rjMLD4o)
# Importando registro 2770 de 2962... (key: VLOYpgy)
# Importando registro 2771 de 2962... (key: 0QRvdVN)
# Importando registro 2772 de 2962... (key: eqW2Mrq)
# Importando registro 2773 de 2962... (key: yP5vNvp)
# Importando registro 2774 de 2962... (key: QKlYMEX)
# Importando registro 2775 de 2962... (key: dWejaDA)
# Importando registro 2776 de 2962... (key: Ek7Ddor)
# Importando registro 2777 de 2962... (key: yP5v2W4)
# Importando registro 2778 de 2962... (key: XxPYorV)
# Importando registro 2779 de 2962... (key: obLdR25)
# Importando registro 2780 de 2962... (key: 44Vv7PX)
# Importando registro 2781 de 2962... (key: xX5yDWd)
# Importando registro 2782 de 2962... (key: LZLYPGz)
# Importando registro 2783 de 2962... (key: 1Aov9E4)
# Importando registro 2784 de 2962... (key: PdJYz7x)
# Importando registro 2785 de 2962... (key: obLd2rb)
# Importando registro 2786 de 2962... (key: xX5yYB5)
# Importando registro 2787 de 2962... (key: MepYze8)
# Importando registro 2788 de 2962... (key: q41WADg)
# Importando registro 2789 de 2962... (key: Np1YWVB)
# Importando registro 2790 de 2962... (key: Ek7DQZq)
# Importando registro 2791 de 2962... (key: lbkWdXN)
# Importando registro 2792 de 2962... (key: GxADz8Z)
# Importando registro 2793 de 2962... (key: 7RrvdW6)
# Importando registro 2794 de 2962... (key: jaAWBVY)
# Importando registro 2795 de 2962... (key: VLOY88J)
# Importando registro 2796 de 2962... (key: RGyYRZd)
# Importando registro 2797 de 2962... (key: 1AovMYb)
# Importando registro 2798 de 2962... (key: KYKDJx7)
# Importando registro 2799 de 2962... (key: MepYJGA)
# Importando registro 2800 de 2962... (key: Np1YJvQ)
# Importando registro 2801 de 2962... (key: KYKDJEk)
# Importando registro 2802 de 2962... (key: Ek7DJ4A)
# Importando registro 2803 de 2962... (key: 68EvQA5)
# Importando registro 2804 de 2962... (key: kdBWRXe)
# Importando registro 2805 de 2962... (key: 9qjv61V)
# Importando registro 2806 de 2962... (key: xX5y0vJ)
# Importando registro 2807 de 2962... (key: lbkW0zp)
# Importando registro 2808 de 2962... (key: 5BPvExb)
# Importando registro 2809 de 2962... (key: ZjrYP0e)
# Importando registro 2810 de 2962... (key: xX5y47G)
# Importando registro 2811 de 2962... (key: lbkWKp6)
# Importando registro 2812 de 2962... (key: QKlYzrp)
# Importando registro 2813 de 2962... (key: gD6ZJkM)
# Importando registro 2814 de 2962... (key: GxADqke)
# Importando registro 2815 de 2962... (key: q41WJl7)
# Importando registro 2816 de 2962... (key: Y5lYJN6)
# Importando registro 2817 de 2962... (key: yP5vdZW)
# Importando registro 2818 de 2962... (key: 68EvpkJ)
# Importando registro 2819 de 2962... (key: BzWD254)
# Importando registro 2820 de 2962... (key: BzWD0ZR)
# Importando registro 2821 de 2962... (key: QKlYkjg)
# Importando registro 2822 de 2962... (key: J9vDMvX)
# Importando registro 2823 de 2962... (key: D46DMjl)
# Importando registro 2824 de 2962... (key: A7eD9PD)
# Importando registro 2825 de 2962... (key: WOVYq1v)
# Importando registro 2826 de 2962... (key: J9vDBWX)
# Importando registro 2827 de 2962... (key: WOVYQMa)
# Importando registro 2828 de 2962... (key: QKlYXRl)
# Importando registro 2829 de 2962... (key: dWejp8q)
# Importando registro 2830 de 2962... (key: 7Rrve6R)
# Importando registro 2831 de 2962... (key: 7Rrv529)
# Importando registro 2832 de 2962... (key: RGyYlYQ)
# Importando registro 2833 de 2962... (key: 0QRv5lN)
# Importando registro 2834 de 2962... (key: 5BPv5gd)
# Importando registro 2835 de 2962... (key: QKlYypg)
# Importando registro 2836 de 2962... (key: PdJYe1V)
# Importando registro 2837 de 2962... (key: LZLYNd1)
# Importando registro 2838 de 2962... (key: vG5L12A)
# Importando registro 2839 de 2962... (key: LZLYNQ2)
# Importando registro 2840 de 2962... (key: obLdaRb)
# Importando registro 2841 de 2962... (key: 0QRvgeB)
# Importando registro 2842 de 2962... (key: gD6Zx04)
# Importando registro 2843 de 2962... (key: VLOYBYv)
# Importando registro 2844 de 2962... (key: LZLYqgJ)
# Importando registro 2845 de 2962... (key: xX5yLbv)
# Importando registro 2846 de 2962... (key: J9vDZER)
# Importando registro 2847 de 2962... (key: obLda8x)
# Importando registro 2848 de 2962... (key: yP5vpQg)
# Importando registro 2849 de 2962... (key: BzWDqx4)
# Importando registro 2850 de 2962... (key: 44Vv0QY)
# Importando registro 2851 de 2962... (key: 2EGvdNV)
# Importando registro 2852 de 2962... (key: gD6ZPxO)
# Importando registro 2853 de 2962... (key: q41W8Dg)
# Importando registro 2854 de 2962... (key: 8148b8x)
# Importando registro 2855 de 2962... (key: Ek7Do8q)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [Errno 60] Operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connection.py:753, in HTTPSConnection.connect(self)
#     752 sock: socket.socket | ssl.SSLSocket
# --> 753 self.sock = sock = self._new_conn()
#     754 server_hostname: str = self.host
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connection.py:207, in HTTPConnection._new_conn(self)
#     206 except SocketTimeout as e:
# --> 207     raise ConnectTimeoutError(
#     208         self,
#     209         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     210     ) from e
#     212 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x12342d160>, 'Connection to webhooks.aloud.com.br timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='webhooks.aloud.com.br', port=443): Max retries exceeded with url: /data/ce7d3845-3acf-4606-835c-63485eb5fe70 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12342d160>, 'Connection to webhooks.aloud.com.br timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[7], line 45
#      42     continue
#      44 print(f"Importando registro {idx} de {total_to_import}... (key: {import_key})")
# ---> 45 response = requests.post(BASE_URL, json=item)
#      46 try:
#      47     resp_json = response.json()
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/projetos/aloud/data_env/venv/lib/python3.12/site-packages/requests/adapters.py:665, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     662 if isinstance(e.reason, ConnectTimeoutError):
#     663     # TODO: Remove this in 3.0.0: see #2811
#     664     if not isinstance(e.reason, NewConnectionError):
# --> 665         raise ConnectTimeout(e, request=request)
#     667 if isinstance(e.reason, ResponseError):
#     668     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='webhooks.aloud.com.br', port=443): Max retries exceeded with url: /data/ce7d3845-3acf-4606-835c-63485eb5fe70 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x12342d160>, 'Connection to webhooks.aloud.com.br timed out. (connect timeout=None)'))
