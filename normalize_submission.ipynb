# %%
import pandas as pd
from aloud_database.aloud_database import Database

db = Database()

# %%
query = """
    SELECT 
        c.id,
        c.conversion_raw_info->>'token' as token,
        c.conversion_raw_info
    FROM
        lead_tracking_prod.conversions c
    WHERE
        c.conversion_type_id = '2'
"""

responses = db.execute_query(query=query)
